# %% [markdown]
# # 환경 설정
# - colab 파일에 첨부된 js파일 옮기기

# %%
#yt-dlp 설치
# !pip install yt-dlp opencv-python-headless

# 패키지 목록 업데이트
# !apt-get update

# FFmpeg 설치
# !apt-get install ffmpeg -y

#opencv 설치
# !pip install opencv-python-headless

#google cloud vision 설치
# !pip install google-cloud-vision
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2024.12.6-py3-none-any.whl.metadata (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.1/172.1 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python-headless) (1.26.4)
# Downloading yt_dlp-2024.12.6-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 26.3 MB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2024.12.6
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,537 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,515 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,748 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,458 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,469 kB]
# Hit:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,627 kB]
# Get:17 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [32.9 kB]
# Get:18 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [49.7 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,331 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,226 kB]
# Fetched 26.4 MB in 3s (8,783 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 55 not upgraded.
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python-headless) (1.26.4)
# Collecting google-cloud-vision
#   Downloading google_cloud_vision-3.8.1-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.19.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision) (1.25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision) (4.25.5)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (1.68.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (1.62.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2024.8.30)
# Downloading google_cloud_vision-3.8.1-py2.py3-none-any.whl (486 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.9/486.9 kB 10.5 MB/s eta 0:00:00
# Installing collected packages: google-cloud-vision
# Successfully installed google-cloud-vision-3.8.1

# %% [markdown]
# # 유튜브에서 영상 다운 받아 1초 간격으로 프레임 추출

# %%
import os
import cv2
import numpy as np
from yt_dlp import YoutubeDL


# 유튜브 동영상 다운로드 함수
def download_youtube_video(url, save_path="downloaded_video.mp4"):
    """
    Downloads a YouTube video using yt-dlp.
    """
    ydl_opts = {
        'format': 'bestvideo+bestaudio/best',  # 최고 품질로 다운로드
        'outtmpl': save_path,  # 저장 파일 경로
        'noplaylist': True,    # 재생 목록 제외
    }
    with YoutubeDL(ydl_opts) as ydl:
        print(f"Downloading video from: {url}")
        ydl.download([url])
    print(f"Video downloaded to: {save_path}")

# YouTube URL 및 다운로드 경로 설정
youtube_url = "https://www.youtube.com/watch?v=BTLQXrw4ZlE"
video_path = "downloaded_video.mp4"

# 동영상 다운로드 실행
download_youtube_video(youtube_url, save_path=video_path)

# !yt-dlp -f best "https://www.youtube.com/watch?v=BTLQXrw4ZlE" -o "downloaded_video.mp4"

# 기존 코드 유지: 다운로드 확인 및 FFmpeg 설치
import os
if os.path.exists("downloaded_video.mp4"):
    print("File downloaded successfully.")
else:
    print("File download failed.")

# !apt-get update
# !apt-get install ffmpeg -y
# !ffmpeg -i downloaded_video.mp4 -vcodec libx264 fixed_video.mp4

# 새로운 코드: 프레임 추출
def get_video_fps(video_path):
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    cap.release()
    return fps

def enhance_image(image):
    blur = cv2.GaussianBlur(image, (0, 0), 3)
    sharpened = cv2.addWeighted(image, 1.5, blur, -0.5, 0)
    return sharpened

def is_frame_changed(prev_frame, current_frame, threshold=30):
    if prev_frame is None:
        return True
    diff = cv2.absdiff(prev_frame, current_frame)
    non_zero_count = np.count_nonzero(diff)
    return non_zero_count > threshold

def extract_all_frames(video_path, output_dir):
    import cv2
    """
    Extracts all frames from a video file and saves them as images.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    cap = cv2.VideoCapture(video_path)
    fps = get_video_fps(video_path)  # FPS 가져오기
    frame_number = 0
    prev_frame = None
    saved_frames = 0  # 저장된 프레임 수를 카운트

    success, image = cap.read()
    if not success:
        print("Error: Unable to read the video file.")
        return

    while success:
        if frame_number % int(fps) == 0:  # 1초 간격으로 프레임 추출
            if is_frame_changed(prev_frame, image):
                enhanced_frame = enhance_image(image)  # 품질 개선
                frame_filename = os.path.join(output_dir, f"frame_{frame_number:05d}.jpg")
                cv2.imwrite(frame_filename, enhanced_frame)
                saved_frames += 1  # 저장된 프레임 수 증가
                print(f"Saved frame: {frame_filename}")
            prev_frame = image

        success, image = cap.read()
        frame_number += 1

    cap.release()
    print(f"All frames saved to: {output_dir}")
    print(f"Total frames extracted: {saved_frames}")  # 총 저장된 프레임 수 출력

# 프레임 추출 실행
video_path = "fixed_video.mp4"  # 동영상 파일 경로
output_dir = "all_frames"      # 저장 폴더 이름

extract_all_frames(video_path, output_dir)
# Out:
# Downloading video from: https://www.youtube.com/watch?v=BTLQXrw4ZlE
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BTLQXrw4ZlE
# [youtube] BTLQXrw4ZlE: Downloading webpage
# [youtube] BTLQXrw4ZlE: Downloading ios player API JSON
# [youtube] BTLQXrw4ZlE: Downloading mweb player API JSON
# [youtube] BTLQXrw4ZlE: Downloading player 3bb1f723
# [youtube] BTLQXrw4ZlE: Downloading m3u8 information
# [info] BTLQXrw4ZlE: Downloading 1 format(s): 616+251
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 160
# [download] Destination: downloaded_video.mp4.f616.mp4
# [download] 100% of  366.65MiB in 00:00:20 at 17.74MiB/s
# [download] Destination: downloaded_video.mp4.f251.webm
# [download] 100% of   13.25MiB in 00:00:01 at 10.84MiB/s
# [Merger] Merging formats into "downloaded_video.mp4.webm"
# Deleting original file downloaded_video.mp4.f616.mp4 (pass -k to keep)
# Deleting original file downloaded_video.mp4.f251.webm (pass -k to keep)
# Video downloaded to: downloaded_video.mp4
# WARNING: "-f best" selects the best pre-merged format which is often not the best option.
#          To let yt-dlp download and merge the best available formats, simply do not pass any format selection.
#          If you know what you are doing and want only the best pre-merged format, use "-f b" instead to suppress this warning
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BTLQXrw4ZlE
# [youtube] BTLQXrw4ZlE: Downloading webpage
# [youtube] BTLQXrw4ZlE: Downloading ios player API JSON
# [youtube] BTLQXrw4ZlE: Downloading mweb player API JSON
# [youtube] BTLQXrw4ZlE: Downloading m3u8 information
# [info] BTLQXrw4ZlE: Downloading 1 format(s): 18
# [download] Destination: downloaded_video.mp4
# [download] 100% of   34.69MiB in 00:00:03 at 9.53MiB/s
# File downloaded successfully.
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 55 not upgraded.
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'downloaded_video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-08-31T16:36:17.000000Z
#   Duration: 00:13:48.21, start: 0.000000, bitrate: 351 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 219 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2023-08-31T16:36:17.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/31/2023.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-08-31T16:36:17.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/31/2023.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x57d322939540] using SAR=1/1
# [libx264 @ 0x57d322939540] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x57d322939540] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x57d322939540] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'fixed_video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2023-08-31T16:36:17.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/31/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-08-31T16:36:17.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/31/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame=24821 fps= 78 q=-1.0 Lsize=   54867kB time=00:13:48.18 bitrate= 542.7kbits/s speed=2.61x
# video:40983kB audio:13027kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.586311%
# [libx264 @ 0x57d322939540] frame I:184   Avg QP:19.54  size: 16037
# [libx264 @ 0x57d322939540] frame P:9183  Avg QP:23.30  size:  3036
# [libx264 @ 0x57d322939540] frame B:15454 Avg QP:26.92  size:   721
# [libx264 @ 0x57d322939540] consecutive B-frames:  2.8% 31.3% 33.5% 32.4%
# [libx264 @ 0x57d322939540] mb I  I16..4: 14.3% 44.4% 41.2%
# [libx264 @ 0x57d322939540] mb P  I16..4:  3.6%  6.7%  1.4%  P16..4: 38.1% 10.9%  3.4%  0.0%  0.0%    skip:35.8%
# [libx264 @ 0x57d322939540] mb B  I16..4:  0.2%  0.4%  0.1%  B16..8: 30.9%  3.1%  0.4%  direct: 0.5%  skip:64.4%  L0:39.2% L1:55.4% BI: 5.4%
# [libx264 @ 0x57d322939540] 8x8 transform intra:55.8% inter:68.1%
# [libx264 @ 0x57d322939540] coded y,uvDC,uvAC intra: 45.2% 40.1% 7.9% inter: 5.8% 4.2% 0.2%
# [libx264 @ 0x57d322939540] i16 v,h,dc,p: 24% 24% 13% 39%
# [libx264 @ 0x57d322939540] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 20% 21%  4%  4%  5%  5%  5%  5%
# [libx264 @ 0x57d322939540] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 20% 17%  5%  6%  6%  6%  5%  4%
# [libx264 @ 0x57d322939540] i8c dc,h,v,p: 61% 18% 16%  5%
# [libx264 @ 0x57d322939540] Weighted P-Frames: Y:4.5% UV:1.2%
# [libx264 @ 0x57d322939540] ref P L0: 66.1% 18.9% 10.7%  4.1%  0.1%
# [libx264 @ 0x57d322939540] ref B L0: 88.7%  9.7%  1.6%
# [libx264 @ 0x57d322939540] ref B L1: 98.7%  1.3%
# [libx264 @ 0x57d322939540] kb/s:405.37
# [aac @ 0x57d3229f98c0] Qavg: 171.322
# Saved frame: all_frames/frame_00000.jpg
# Saved frame: all_frames/frame_00029.jpg
# Saved frame: all_frames/frame_00058.jpg
# Saved frame: all_frames/frame_00087.jpg
# Saved frame: all_frames/frame_00116.jpg
# Saved frame: all_frames/frame_00145.jpg
# Saved frame: all_frames/frame_00174.jpg
# Saved frame: all_frames/frame_00203.jpg
# Saved frame: all_frames/frame_00232.jpg
# Saved frame: all_frames/frame_00261.jpg
# Saved frame: all_frames/frame_00290.jpg
# Saved frame: all_frames/frame_00319.jpg
# Saved frame: all_frames/frame_00348.jpg
# Saved frame: all_frames/frame_00377.jpg
# Saved frame: all_frames/frame_00406.jpg
# Saved frame: all_frames/frame_00435.jpg
# Saved frame: all_frames/frame_00464.jpg
# Saved frame: all_frames/frame_00493.jpg
# Saved frame: all_frames/frame_00522.jpg
# Saved frame: all_frames/frame_00551.jpg
# Saved frame: all_frames/frame_00580.jpg
# Saved frame: all_frames/frame_00609.jpg
# Saved frame: all_frames/frame_00638.jpg
# Saved frame: all_frames/frame_00667.jpg
# Saved frame: all_frames/frame_00696.jpg
# Saved frame: all_frames/frame_00725.jpg
# Saved frame: all_frames/frame_00754.jpg
# Saved frame: all_frames/frame_00783.jpg
# Saved frame: all_frames/frame_00812.jpg
# Saved frame: all_frames/frame_00841.jpg
# Saved frame: all_frames/frame_00870.jpg
# Saved frame: all_frames/frame_00899.jpg
# Saved frame: all_frames/frame_00928.jpg
# Saved frame: all_frames/frame_00957.jpg
# Saved frame: all_frames/frame_00986.jpg
# Saved frame: all_frames/frame_01015.jpg
# Saved frame: all_frames/frame_01044.jpg
# Saved frame: all_frames/frame_01073.jpg
# Saved frame: all_frames/frame_01102.jpg
# Saved frame: all_frames/frame_01131.jpg
# Saved frame: all_frames/frame_01160.jpg
# Saved frame: all_frames/frame_01189.jpg
# Saved frame: all_frames/frame_01218.jpg
# Saved frame: all_frames/frame_01247.jpg
# Saved frame: all_frames/frame_01276.jpg
# Saved frame: all_frames/frame_01305.jpg
# Saved frame: all_frames/frame_01334.jpg
# Saved frame: all_frames/frame_01363.jpg
# Saved frame: all_frames/frame_01392.jpg
# Saved frame: all_frames/frame_01421.jpg
# Saved frame: all_frames/frame_01450.jpg
# Saved frame: all_frames/frame_01479.jpg
# Saved frame: all_frames/frame_01508.jpg
# Saved frame: all_frames/frame_01537.jpg
# Saved frame: all_frames/frame_01566.jpg
# Saved frame: all_frames/frame_01595.jpg
# Saved frame: all_frames/frame_01624.jpg
# Saved frame: all_frames/frame_01653.jpg
# Saved frame: all_frames/frame_01682.jpg
# Saved frame: all_frames/frame_01711.jpg
# Saved frame: all_frames/frame_01740.jpg
# Saved frame: all_frames/frame_01769.jpg
# Saved frame: all_frames/frame_01798.jpg
# Saved frame: all_frames/frame_01827.jpg
# Saved frame: all_frames/frame_01856.jpg
# Saved frame: all_frames/frame_01885.jpg
# Saved frame: all_frames/frame_01914.jpg
# Saved frame: all_frames/frame_01943.jpg
# Saved frame: all_frames/frame_01972.jpg
# Saved frame: all_frames/frame_02001.jpg
# Saved frame: all_frames/frame_02030.jpg
# Saved frame: all_frames/frame_02059.jpg
# Saved frame: all_frames/frame_02088.jpg
# Saved frame: all_frames/frame_02117.jpg
# Saved frame: all_frames/frame_02146.jpg
# Saved frame: all_frames/frame_02175.jpg
# Saved frame: all_frames/frame_02204.jpg
# Saved frame: all_frames/frame_02233.jpg
# Saved frame: all_frames/frame_02262.jpg
# Saved frame: all_frames/frame_02291.jpg
# Saved frame: all_frames/frame_02320.jpg
# Saved frame: all_frames/frame_02349.jpg
# Saved frame: all_frames/frame_02378.jpg
# Saved frame: all_frames/frame_02407.jpg
# Saved frame: all_frames/frame_02436.jpg
# Saved frame: all_frames/frame_02465.jpg
# Saved frame: all_frames/frame_02494.jpg
# Saved frame: all_frames/frame_02523.jpg
# Saved frame: all_frames/frame_02552.jpg
# Saved frame: all_frames/frame_02581.jpg
# Saved frame: all_frames/frame_02610.jpg
# Saved frame: all_frames/frame_02639.jpg
# Saved frame: all_frames/frame_02668.jpg
# Saved frame: all_frames/frame_02697.jpg
# Saved frame: all_frames/frame_02726.jpg
# Saved frame: all_frames/frame_02755.jpg
# Saved frame: all_frames/frame_02784.jpg
# Saved frame: all_frames/frame_02813.jpg
# Saved frame: all_frames/frame_02842.jpg
# Saved frame: all_frames/frame_02871.jpg
# Saved frame: all_frames/frame_02900.jpg
# Saved frame: all_frames/frame_02929.jpg
# Saved frame: all_frames/frame_02958.jpg
# Saved frame: all_frames/frame_02987.jpg
# Saved frame: all_frames/frame_03016.jpg
# Saved frame: all_frames/frame_03045.jpg
# Saved frame: all_frames/frame_03074.jpg
# Saved frame: all_frames/frame_03103.jpg
# Saved frame: all_frames/frame_03132.jpg
# Saved frame: all_frames/frame_03161.jpg
# Saved frame: all_frames/frame_03190.jpg
# Saved frame: all_frames/frame_03219.jpg
# Saved frame: all_frames/frame_03248.jpg
# Saved frame: all_frames/frame_03277.jpg
# Saved frame: all_frames/frame_03306.jpg
# Saved frame: all_frames/frame_03335.jpg
# Saved frame: all_frames/frame_03364.jpg
# Saved frame: all_frames/frame_03393.jpg
# Saved frame: all_frames/frame_03422.jpg
# Saved frame: all_frames/frame_03451.jpg
# Saved frame: all_frames/frame_03480.jpg
# Saved frame: all_frames/frame_03509.jpg
# Saved frame: all_frames/frame_03538.jpg
# Saved frame: all_frames/frame_03567.jpg
# Saved frame: all_frames/frame_03596.jpg
# Saved frame: all_frames/frame_03625.jpg
# Saved frame: all_frames/frame_03654.jpg
# Saved frame: all_frames/frame_03683.jpg
# Saved frame: all_frames/frame_03712.jpg
# Saved frame: all_frames/frame_03741.jpg
# Saved frame: all_frames/frame_03770.jpg
# Saved frame: all_frames/frame_03799.jpg
# Saved frame: all_frames/frame_03828.jpg
# Saved frame: all_frames/frame_03857.jpg
# Saved frame: all_frames/frame_03886.jpg
# Saved frame: all_frames/frame_03915.jpg
# Saved frame: all_frames/frame_03944.jpg
# Saved frame: all_frames/frame_03973.jpg
# Saved frame: all_frames/frame_04002.jpg
# Saved frame: all_frames/frame_04031.jpg
# Saved frame: all_frames/frame_04060.jpg
# Saved frame: all_frames/frame_04089.jpg
# Saved frame: all_frames/frame_04118.jpg
# Saved frame: all_frames/frame_04147.jpg
# Saved frame: all_frames/frame_04176.jpg
# Saved frame: all_frames/frame_04205.jpg
# Saved frame: all_frames/frame_04234.jpg
# Saved frame: all_frames/frame_04263.jpg
# Saved frame: all_frames/frame_04292.jpg
# Saved frame: all_frames/frame_04321.jpg
# Saved frame: all_frames/frame_04350.jpg
# Saved frame: all_frames/frame_04379.jpg
# Saved frame: all_frames/frame_04408.jpg
# Saved frame: all_frames/frame_04437.jpg
# Saved frame: all_frames/frame_04466.jpg
# Saved frame: all_frames/frame_04495.jpg
# Saved frame: all_frames/frame_04524.jpg
# Saved frame: all_frames/frame_04553.jpg
# Saved frame: all_frames/frame_04582.jpg
# Saved frame: all_frames/frame_04611.jpg
# Saved frame: all_frames/frame_04640.jpg
# Saved frame: all_frames/frame_04669.jpg
# Saved frame: all_frames/frame_04698.jpg
# Saved frame: all_frames/frame_04727.jpg
# Saved frame: all_frames/frame_04756.jpg
# Saved frame: all_frames/frame_04785.jpg
# Saved frame: all_frames/frame_04814.jpg
# Saved frame: all_frames/frame_04843.jpg
# Saved frame: all_frames/frame_04872.jpg
# Saved frame: all_frames/frame_04901.jpg
# Saved frame: all_frames/frame_04930.jpg
# Saved frame: all_frames/frame_04959.jpg
# Saved frame: all_frames/frame_04988.jpg
# Saved frame: all_frames/frame_05017.jpg
# Saved frame: all_frames/frame_05046.jpg
# Saved frame: all_frames/frame_05075.jpg
# Saved frame: all_frames/frame_05104.jpg
# Saved frame: all_frames/frame_05133.jpg
# Saved frame: all_frames/frame_05162.jpg
# Saved frame: all_frames/frame_05191.jpg
# Saved frame: all_frames/frame_05220.jpg
# Saved frame: all_frames/frame_05249.jpg
# Saved frame: all_frames/frame_05278.jpg
# Saved frame: all_frames/frame_05307.jpg
# Saved frame: all_frames/frame_05336.jpg
# Saved frame: all_frames/frame_05365.jpg
# Saved frame: all_frames/frame_05394.jpg
# Saved frame: all_frames/frame_05423.jpg
# Saved frame: all_frames/frame_05452.jpg
# Saved frame: all_frames/frame_05481.jpg
# Saved frame: all_frames/frame_05510.jpg
# Saved frame: all_frames/frame_05539.jpg
# Saved frame: all_frames/frame_05568.jpg
# Saved frame: all_frames/frame_05597.jpg
# Saved frame: all_frames/frame_05626.jpg
# Saved frame: all_frames/frame_05655.jpg
# Saved frame: all_frames/frame_05684.jpg
# Saved frame: all_frames/frame_05713.jpg
# Saved frame: all_frames/frame_05742.jpg
# Saved frame: all_frames/frame_05771.jpg
# Saved frame: all_frames/frame_05800.jpg
# Saved frame: all_frames/frame_05829.jpg
# Saved frame: all_frames/frame_05858.jpg
# Saved frame: all_frames/frame_05887.jpg
# Saved frame: all_frames/frame_05916.jpg
# Saved frame: all_frames/frame_05945.jpg
# Saved frame: all_frames/frame_05974.jpg
# Saved frame: all_frames/frame_06003.jpg
# Saved frame: all_frames/frame_06032.jpg
# Saved frame: all_frames/frame_06061.jpg
# Saved frame: all_frames/frame_06090.jpg
# Saved frame: all_frames/frame_06119.jpg
# Saved frame: all_frames/frame_06148.jpg
# Saved frame: all_frames/frame_06177.jpg
# Saved frame: all_frames/frame_06206.jpg
# Saved frame: all_frames/frame_06235.jpg
# Saved frame: all_frames/frame_06264.jpg
# Saved frame: all_frames/frame_06293.jpg
# Saved frame: all_frames/frame_06322.jpg
# Saved frame: all_frames/frame_06351.jpg
# Saved frame: all_frames/frame_06380.jpg
# Saved frame: all_frames/frame_06409.jpg
# Saved frame: all_frames/frame_06438.jpg
# Saved frame: all_frames/frame_06467.jpg
# Saved frame: all_frames/frame_06496.jpg
# Saved frame: all_frames/frame_06525.jpg
# Saved frame: all_frames/frame_06554.jpg
# Saved frame: all_frames/frame_06583.jpg
# Saved frame: all_frames/frame_06612.jpg
# Saved frame: all_frames/frame_06641.jpg
# Saved frame: all_frames/frame_06670.jpg
# Saved frame: all_frames/frame_06699.jpg
# Saved frame: all_frames/frame_06728.jpg
# Saved frame: all_frames/frame_06757.jpg
# Saved frame: all_frames/frame_06786.jpg
# Saved frame: all_frames/frame_06815.jpg
# Saved frame: all_frames/frame_06844.jpg
# Saved frame: all_frames/frame_06873.jpg
# Saved frame: all_frames/frame_06902.jpg
# Saved frame: all_frames/frame_06931.jpg
# Saved frame: all_frames/frame_06960.jpg
# Saved frame: all_frames/frame_06989.jpg
# Saved frame: all_frames/frame_07018.jpg
# Saved frame: all_frames/frame_07047.jpg
# Saved frame: all_frames/frame_07076.jpg
# Saved frame: all_frames/frame_07105.jpg
# Saved frame: all_frames/frame_07134.jpg
# Saved frame: all_frames/frame_07163.jpg
# Saved frame: all_frames/frame_07192.jpg
# Saved frame: all_frames/frame_07221.jpg
# Saved frame: all_frames/frame_07250.jpg
# Saved frame: all_frames/frame_07279.jpg
# Saved frame: all_frames/frame_07308.jpg
# Saved frame: all_frames/frame_07337.jpg
# Saved frame: all_frames/frame_07366.jpg
# Saved frame: all_frames/frame_07395.jpg
# Saved frame: all_frames/frame_07424.jpg
# Saved frame: all_frames/frame_07453.jpg
# Saved frame: all_frames/frame_07482.jpg
# Saved frame: all_frames/frame_07511.jpg
# Saved frame: all_frames/frame_07540.jpg
# Saved frame: all_frames/frame_07569.jpg
# Saved frame: all_frames/frame_07598.jpg
# Saved frame: all_frames/frame_07627.jpg
# Saved frame: all_frames/frame_07656.jpg
# Saved frame: all_frames/frame_07685.jpg
# Saved frame: all_frames/frame_07714.jpg
# Saved frame: all_frames/frame_07743.jpg
# Saved frame: all_frames/frame_07772.jpg
# Saved frame: all_frames/frame_07801.jpg
# Saved frame: all_frames/frame_07830.jpg
# Saved frame: all_frames/frame_07859.jpg
# Saved frame: all_frames/frame_07888.jpg
# Saved frame: all_frames/frame_07917.jpg
# Saved frame: all_frames/frame_07946.jpg
# Saved frame: all_frames/frame_07975.jpg
# Saved frame: all_frames/frame_08004.jpg
# Saved frame: all_frames/frame_08033.jpg
# Saved frame: all_frames/frame_08062.jpg
# Saved frame: all_frames/frame_08091.jpg
# Saved frame: all_frames/frame_08120.jpg
# Saved frame: all_frames/frame_08149.jpg
# Saved frame: all_frames/frame_08178.jpg
# Saved frame: all_frames/frame_08207.jpg
# Saved frame: all_frames/frame_08236.jpg
# Saved frame: all_frames/frame_08265.jpg
# Saved frame: all_frames/frame_08294.jpg
# Saved frame: all_frames/frame_08323.jpg
# Saved frame: all_frames/frame_08352.jpg
# Saved frame: all_frames/frame_08381.jpg
# Saved frame: all_frames/frame_08410.jpg
# Saved frame: all_frames/frame_08439.jpg
# Saved frame: all_frames/frame_08468.jpg
# Saved frame: all_frames/frame_08497.jpg
# Saved frame: all_frames/frame_08526.jpg
# Saved frame: all_frames/frame_08555.jpg
# Saved frame: all_frames/frame_08584.jpg
# Saved frame: all_frames/frame_08613.jpg
# Saved frame: all_frames/frame_08642.jpg
# Saved frame: all_frames/frame_08671.jpg
# Saved frame: all_frames/frame_08700.jpg
# Saved frame: all_frames/frame_08729.jpg
# Saved frame: all_frames/frame_08758.jpg
# Saved frame: all_frames/frame_08787.jpg
# Saved frame: all_frames/frame_08816.jpg
# Saved frame: all_frames/frame_08845.jpg
# Saved frame: all_frames/frame_08874.jpg
# Saved frame: all_frames/frame_08903.jpg
# Saved frame: all_frames/frame_08932.jpg
# Saved frame: all_frames/frame_08961.jpg
# Saved frame: all_frames/frame_08990.jpg
# Saved frame: all_frames/frame_09019.jpg
# Saved frame: all_frames/frame_09048.jpg
# Saved frame: all_frames/frame_09077.jpg
# Saved frame: all_frames/frame_09106.jpg
# Saved frame: all_frames/frame_09135.jpg
# Saved frame: all_frames/frame_09164.jpg
# Saved frame: all_frames/frame_09193.jpg
# Saved frame: all_frames/frame_09222.jpg
# Saved frame: all_frames/frame_09251.jpg
# Saved frame: all_frames/frame_09280.jpg
# Saved frame: all_frames/frame_09309.jpg
# Saved frame: all_frames/frame_09338.jpg
# Saved frame: all_frames/frame_09367.jpg
# Saved frame: all_frames/frame_09396.jpg
# Saved frame: all_frames/frame_09425.jpg
# Saved frame: all_frames/frame_09454.jpg
# Saved frame: all_frames/frame_09483.jpg
# Saved frame: all_frames/frame_09512.jpg
# Saved frame: all_frames/frame_09541.jpg
# Saved frame: all_frames/frame_09570.jpg
# Saved frame: all_frames/frame_09599.jpg
# Saved frame: all_frames/frame_09628.jpg
# Saved frame: all_frames/frame_09657.jpg
# Saved frame: all_frames/frame_09686.jpg
# Saved frame: all_frames/frame_09715.jpg
# Saved frame: all_frames/frame_09744.jpg
# Saved frame: all_frames/frame_09773.jpg
# Saved frame: all_frames/frame_09802.jpg
# Saved frame: all_frames/frame_09831.jpg
# Saved frame: all_frames/frame_09860.jpg
# Saved frame: all_frames/frame_09889.jpg
# Saved frame: all_frames/frame_09918.jpg
# Saved frame: all_frames/frame_09947.jpg
# Saved frame: all_frames/frame_09976.jpg
# Saved frame: all_frames/frame_10005.jpg
# Saved frame: all_frames/frame_10034.jpg
# Saved frame: all_frames/frame_10063.jpg
# Saved frame: all_frames/frame_10092.jpg
# Saved frame: all_frames/frame_10121.jpg
# Saved frame: all_frames/frame_10150.jpg
# Saved frame: all_frames/frame_10179.jpg
# Saved frame: all_frames/frame_10208.jpg
# Saved frame: all_frames/frame_10237.jpg
# Saved frame: all_frames/frame_10266.jpg
# Saved frame: all_frames/frame_10295.jpg
# Saved frame: all_frames/frame_10324.jpg
# Saved frame: all_frames/frame_10353.jpg
# Saved frame: all_frames/frame_10382.jpg
# Saved frame: all_frames/frame_10411.jpg
# Saved frame: all_frames/frame_10440.jpg
# Saved frame: all_frames/frame_10469.jpg
# Saved frame: all_frames/frame_10498.jpg
# Saved frame: all_frames/frame_10527.jpg
# Saved frame: all_frames/frame_10556.jpg
# Saved frame: all_frames/frame_10585.jpg
# Saved frame: all_frames/frame_10614.jpg
# Saved frame: all_frames/frame_10643.jpg
# Saved frame: all_frames/frame_10672.jpg
# Saved frame: all_frames/frame_10701.jpg
# Saved frame: all_frames/frame_10730.jpg
# Saved frame: all_frames/frame_10759.jpg
# Saved frame: all_frames/frame_10788.jpg
# Saved frame: all_frames/frame_10817.jpg
# Saved frame: all_frames/frame_10846.jpg
# Saved frame: all_frames/frame_10875.jpg
# Saved frame: all_frames/frame_10904.jpg
# Saved frame: all_frames/frame_10933.jpg
# Saved frame: all_frames/frame_10962.jpg
# Saved frame: all_frames/frame_10991.jpg
# Saved frame: all_frames/frame_11020.jpg
# Saved frame: all_frames/frame_11049.jpg
# Saved frame: all_frames/frame_11078.jpg
# Saved frame: all_frames/frame_11107.jpg
# Saved frame: all_frames/frame_11136.jpg
# Saved frame: all_frames/frame_11165.jpg
# Saved frame: all_frames/frame_11194.jpg
# Saved frame: all_frames/frame_11223.jpg
# Saved frame: all_frames/frame_11252.jpg
# Saved frame: all_frames/frame_11281.jpg
# Saved frame: all_frames/frame_11310.jpg
# Saved frame: all_frames/frame_11339.jpg
# Saved frame: all_frames/frame_11368.jpg
# Saved frame: all_frames/frame_11397.jpg
# Saved frame: all_frames/frame_11426.jpg
# Saved frame: all_frames/frame_11455.jpg
# Saved frame: all_frames/frame_11484.jpg
# Saved frame: all_frames/frame_11513.jpg
# Saved frame: all_frames/frame_11542.jpg
# Saved frame: all_frames/frame_11571.jpg
# Saved frame: all_frames/frame_11600.jpg
# Saved frame: all_frames/frame_11629.jpg
# Saved frame: all_frames/frame_11658.jpg
# Saved frame: all_frames/frame_11687.jpg
# Saved frame: all_frames/frame_11716.jpg
# Saved frame: all_frames/frame_11745.jpg
# Saved frame: all_frames/frame_11774.jpg
# Saved frame: all_frames/frame_11803.jpg
# Saved frame: all_frames/frame_11832.jpg
# Saved frame: all_frames/frame_11861.jpg
# Saved frame: all_frames/frame_11890.jpg
# Saved frame: all_frames/frame_11919.jpg
# Saved frame: all_frames/frame_11948.jpg
# Saved frame: all_frames/frame_11977.jpg
# Saved frame: all_frames/frame_12006.jpg
# Saved frame: all_frames/frame_12035.jpg
# Saved frame: all_frames/frame_12064.jpg
# Saved frame: all_frames/frame_12093.jpg
# Saved frame: all_frames/frame_12122.jpg
# Saved frame: all_frames/frame_12151.jpg
# Saved frame: all_frames/frame_12180.jpg
# Saved frame: all_frames/frame_12209.jpg
# Saved frame: all_frames/frame_12238.jpg
# Saved frame: all_frames/frame_12267.jpg
# Saved frame: all_frames/frame_12296.jpg
# Saved frame: all_frames/frame_12325.jpg
# Saved frame: all_frames/frame_12354.jpg
# Saved frame: all_frames/frame_12383.jpg
# Saved frame: all_frames/frame_12412.jpg
# Saved frame: all_frames/frame_12441.jpg
# Saved frame: all_frames/frame_12470.jpg
# Saved frame: all_frames/frame_12499.jpg
# Saved frame: all_frames/frame_12528.jpg
# Saved frame: all_frames/frame_12557.jpg
# Saved frame: all_frames/frame_12586.jpg
# Saved frame: all_frames/frame_12615.jpg
# Saved frame: all_frames/frame_12644.jpg
# Saved frame: all_frames/frame_12673.jpg
# Saved frame: all_frames/frame_12702.jpg
# Saved frame: all_frames/frame_12731.jpg
# Saved frame: all_frames/frame_12760.jpg
# Saved frame: all_frames/frame_12789.jpg
# Saved frame: all_frames/frame_12818.jpg
# Saved frame: all_frames/frame_12847.jpg
# Saved frame: all_frames/frame_12876.jpg
# Saved frame: all_frames/frame_12905.jpg
# Saved frame: all_frames/frame_12934.jpg
# Saved frame: all_frames/frame_12963.jpg
# Saved frame: all_frames/frame_12992.jpg
# Saved frame: all_frames/frame_13021.jpg
# Saved frame: all_frames/frame_13050.jpg
# Saved frame: all_frames/frame_13079.jpg
# Saved frame: all_frames/frame_13108.jpg
# Saved frame: all_frames/frame_13137.jpg
# Saved frame: all_frames/frame_13166.jpg
# Saved frame: all_frames/frame_13195.jpg
# Saved frame: all_frames/frame_13224.jpg
# Saved frame: all_frames/frame_13253.jpg
# Saved frame: all_frames/frame_13282.jpg
# Saved frame: all_frames/frame_13311.jpg
# Saved frame: all_frames/frame_13340.jpg
# Saved frame: all_frames/frame_13369.jpg
# Saved frame: all_frames/frame_13398.jpg
# Saved frame: all_frames/frame_13427.jpg
# Saved frame: all_frames/frame_13456.jpg
# Saved frame: all_frames/frame_13485.jpg
# Saved frame: all_frames/frame_13514.jpg
# Saved frame: all_frames/frame_13543.jpg
# Saved frame: all_frames/frame_13572.jpg
# Saved frame: all_frames/frame_13601.jpg
# Saved frame: all_frames/frame_13630.jpg
# Saved frame: all_frames/frame_13659.jpg
# Saved frame: all_frames/frame_13688.jpg
# Saved frame: all_frames/frame_13717.jpg
# Saved frame: all_frames/frame_13746.jpg
# Saved frame: all_frames/frame_13775.jpg
# Saved frame: all_frames/frame_13804.jpg
# Saved frame: all_frames/frame_13833.jpg
# Saved frame: all_frames/frame_13862.jpg
# Saved frame: all_frames/frame_13891.jpg
# Saved frame: all_frames/frame_13920.jpg
# Saved frame: all_frames/frame_13949.jpg
# Saved frame: all_frames/frame_13978.jpg
# Saved frame: all_frames/frame_14007.jpg
# Saved frame: all_frames/frame_14036.jpg
# Saved frame: all_frames/frame_14065.jpg
# Saved frame: all_frames/frame_14094.jpg
# Saved frame: all_frames/frame_14123.jpg
# Saved frame: all_frames/frame_14152.jpg
# Saved frame: all_frames/frame_14181.jpg
# Saved frame: all_frames/frame_14210.jpg
# Saved frame: all_frames/frame_14239.jpg
# Saved frame: all_frames/frame_14268.jpg
# Saved frame: all_frames/frame_14297.jpg
# Saved frame: all_frames/frame_14326.jpg
# Saved frame: all_frames/frame_14355.jpg
# Saved frame: all_frames/frame_14384.jpg
# Saved frame: all_frames/frame_14413.jpg
# Saved frame: all_frames/frame_14442.jpg
# Saved frame: all_frames/frame_14471.jpg
# Saved frame: all_frames/frame_14500.jpg
# Saved frame: all_frames/frame_14529.jpg
# Saved frame: all_frames/frame_14558.jpg
# Saved frame: all_frames/frame_14587.jpg
# Saved frame: all_frames/frame_14616.jpg
# Saved frame: all_frames/frame_14645.jpg
# Saved frame: all_frames/frame_14674.jpg
# Saved frame: all_frames/frame_14703.jpg
# Saved frame: all_frames/frame_14732.jpg
# Saved frame: all_frames/frame_14761.jpg
# Saved frame: all_frames/frame_14790.jpg
# Saved frame: all_frames/frame_14819.jpg
# Saved frame: all_frames/frame_14848.jpg
# Saved frame: all_frames/frame_14877.jpg
# Saved frame: all_frames/frame_14906.jpg
# Saved frame: all_frames/frame_14935.jpg
# Saved frame: all_frames/frame_14964.jpg
# Saved frame: all_frames/frame_14993.jpg
# Saved frame: all_frames/frame_15022.jpg
# Saved frame: all_frames/frame_15051.jpg
# Saved frame: all_frames/frame_15080.jpg
# Saved frame: all_frames/frame_15109.jpg
# Saved frame: all_frames/frame_15138.jpg
# Saved frame: all_frames/frame_15167.jpg
# Saved frame: all_frames/frame_15196.jpg
# Saved frame: all_frames/frame_15225.jpg
# Saved frame: all_frames/frame_15254.jpg
# Saved frame: all_frames/frame_15283.jpg
# Saved frame: all_frames/frame_15312.jpg
# Saved frame: all_frames/frame_15341.jpg
# Saved frame: all_frames/frame_15370.jpg
# Saved frame: all_frames/frame_15399.jpg
# Saved frame: all_frames/frame_15428.jpg
# Saved frame: all_frames/frame_15457.jpg
# Saved frame: all_frames/frame_15486.jpg
# Saved frame: all_frames/frame_15515.jpg
# Saved frame: all_frames/frame_15544.jpg
# Saved frame: all_frames/frame_15573.jpg
# Saved frame: all_frames/frame_15602.jpg
# Saved frame: all_frames/frame_15631.jpg
# Saved frame: all_frames/frame_15660.jpg
# Saved frame: all_frames/frame_15689.jpg
# Saved frame: all_frames/frame_15718.jpg
# Saved frame: all_frames/frame_15747.jpg
# Saved frame: all_frames/frame_15776.jpg
# Saved frame: all_frames/frame_15805.jpg
# Saved frame: all_frames/frame_15834.jpg
# Saved frame: all_frames/frame_15863.jpg
# Saved frame: all_frames/frame_15892.jpg
# Saved frame: all_frames/frame_15921.jpg
# Saved frame: all_frames/frame_15950.jpg
# Saved frame: all_frames/frame_15979.jpg
# Saved frame: all_frames/frame_16008.jpg
# Saved frame: all_frames/frame_16037.jpg
# Saved frame: all_frames/frame_16066.jpg
# Saved frame: all_frames/frame_16095.jpg
# Saved frame: all_frames/frame_16124.jpg
# Saved frame: all_frames/frame_16153.jpg
# Saved frame: all_frames/frame_16182.jpg
# Saved frame: all_frames/frame_16211.jpg
# Saved frame: all_frames/frame_16240.jpg
# Saved frame: all_frames/frame_16269.jpg
# Saved frame: all_frames/frame_16298.jpg
# Saved frame: all_frames/frame_16327.jpg
# Saved frame: all_frames/frame_16356.jpg
# Saved frame: all_frames/frame_16385.jpg
# Saved frame: all_frames/frame_16414.jpg
# Saved frame: all_frames/frame_16443.jpg
# Saved frame: all_frames/frame_16472.jpg
# Saved frame: all_frames/frame_16501.jpg
# Saved frame: all_frames/frame_16530.jpg
# Saved frame: all_frames/frame_16559.jpg
# Saved frame: all_frames/frame_16588.jpg
# Saved frame: all_frames/frame_16617.jpg
# Saved frame: all_frames/frame_16646.jpg
# Saved frame: all_frames/frame_16675.jpg
# Saved frame: all_frames/frame_16704.jpg
# Saved frame: all_frames/frame_16733.jpg
# Saved frame: all_frames/frame_16762.jpg
# Saved frame: all_frames/frame_16791.jpg
# Saved frame: all_frames/frame_16820.jpg
# Saved frame: all_frames/frame_16849.jpg
# Saved frame: all_frames/frame_16878.jpg
# Saved frame: all_frames/frame_16907.jpg
# Saved frame: all_frames/frame_16936.jpg
# Saved frame: all_frames/frame_16965.jpg
# Saved frame: all_frames/frame_16994.jpg
# Saved frame: all_frames/frame_17023.jpg
# Saved frame: all_frames/frame_17052.jpg
# Saved frame: all_frames/frame_17081.jpg
# Saved frame: all_frames/frame_17110.jpg
# Saved frame: all_frames/frame_17139.jpg
# Saved frame: all_frames/frame_17168.jpg
# Saved frame: all_frames/frame_17197.jpg
# Saved frame: all_frames/frame_17226.jpg
# Saved frame: all_frames/frame_17255.jpg
# Saved frame: all_frames/frame_17284.jpg
# Saved frame: all_frames/frame_17313.jpg
# Saved frame: all_frames/frame_17342.jpg
# Saved frame: all_frames/frame_17371.jpg
# Saved frame: all_frames/frame_17400.jpg
# Saved frame: all_frames/frame_17429.jpg
# Saved frame: all_frames/frame_17458.jpg
# Saved frame: all_frames/frame_17487.jpg
# Saved frame: all_frames/frame_17516.jpg
# Saved frame: all_frames/frame_17545.jpg
# Saved frame: all_frames/frame_17574.jpg
# Saved frame: all_frames/frame_17603.jpg
# Saved frame: all_frames/frame_17632.jpg
# Saved frame: all_frames/frame_17661.jpg
# Saved frame: all_frames/frame_17690.jpg
# Saved frame: all_frames/frame_17719.jpg
# Saved frame: all_frames/frame_17748.jpg
# Saved frame: all_frames/frame_17777.jpg
# Saved frame: all_frames/frame_17806.jpg
# Saved frame: all_frames/frame_17835.jpg
# Saved frame: all_frames/frame_17864.jpg
# Saved frame: all_frames/frame_17893.jpg
# Saved frame: all_frames/frame_17922.jpg
# Saved frame: all_frames/frame_17951.jpg
# Saved frame: all_frames/frame_17980.jpg
# Saved frame: all_frames/frame_18009.jpg
# Saved frame: all_frames/frame_18038.jpg
# Saved frame: all_frames/frame_18067.jpg
# Saved frame: all_frames/frame_18096.jpg
# Saved frame: all_frames/frame_18125.jpg
# Saved frame: all_frames/frame_18154.jpg
# Saved frame: all_frames/frame_18183.jpg
# Saved frame: all_frames/frame_18212.jpg
# Saved frame: all_frames/frame_18241.jpg
# Saved frame: all_frames/frame_18270.jpg
# Saved frame: all_frames/frame_18299.jpg
# Saved frame: all_frames/frame_18328.jpg
# Saved frame: all_frames/frame_18357.jpg
# Saved frame: all_frames/frame_18386.jpg
# Saved frame: all_frames/frame_18415.jpg
# Saved frame: all_frames/frame_18444.jpg
# Saved frame: all_frames/frame_18473.jpg
# Saved frame: all_frames/frame_18502.jpg
# Saved frame: all_frames/frame_18531.jpg
# Saved frame: all_frames/frame_18560.jpg
# Saved frame: all_frames/frame_18589.jpg
# Saved frame: all_frames/frame_18618.jpg
# Saved frame: all_frames/frame_18647.jpg
# Saved frame: all_frames/frame_18676.jpg
# Saved frame: all_frames/frame_18705.jpg
# Saved frame: all_frames/frame_18734.jpg
# Saved frame: all_frames/frame_18763.jpg
# Saved frame: all_frames/frame_18792.jpg
# Saved frame: all_frames/frame_18821.jpg
# Saved frame: all_frames/frame_18850.jpg
# Saved frame: all_frames/frame_18879.jpg
# Saved frame: all_frames/frame_18908.jpg
# Saved frame: all_frames/frame_18937.jpg
# Saved frame: all_frames/frame_18966.jpg
# Saved frame: all_frames/frame_18995.jpg
# Saved frame: all_frames/frame_19024.jpg
# Saved frame: all_frames/frame_19053.jpg
# Saved frame: all_frames/frame_19082.jpg
# Saved frame: all_frames/frame_19111.jpg
# Saved frame: all_frames/frame_19140.jpg
# Saved frame: all_frames/frame_19169.jpg
# Saved frame: all_frames/frame_19198.jpg
# Saved frame: all_frames/frame_19227.jpg
# Saved frame: all_frames/frame_19256.jpg
# Saved frame: all_frames/frame_19285.jpg
# Saved frame: all_frames/frame_19314.jpg
# Saved frame: all_frames/frame_19343.jpg
# Saved frame: all_frames/frame_19372.jpg
# Saved frame: all_frames/frame_19401.jpg
# Saved frame: all_frames/frame_19430.jpg
# Saved frame: all_frames/frame_19459.jpg
# Saved frame: all_frames/frame_19488.jpg
# Saved frame: all_frames/frame_19517.jpg
# Saved frame: all_frames/frame_19546.jpg
# Saved frame: all_frames/frame_19575.jpg
# Saved frame: all_frames/frame_19604.jpg
# Saved frame: all_frames/frame_19633.jpg
# Saved frame: all_frames/frame_19662.jpg
# Saved frame: all_frames/frame_19691.jpg
# Saved frame: all_frames/frame_19720.jpg
# Saved frame: all_frames/frame_19749.jpg
# Saved frame: all_frames/frame_19778.jpg
# Saved frame: all_frames/frame_19807.jpg
# Saved frame: all_frames/frame_19836.jpg
# Saved frame: all_frames/frame_19865.jpg
# Saved frame: all_frames/frame_19894.jpg
# Saved frame: all_frames/frame_19923.jpg
# Saved frame: all_frames/frame_19952.jpg
# Saved frame: all_frames/frame_19981.jpg
# Saved frame: all_frames/frame_20010.jpg
# Saved frame: all_frames/frame_20039.jpg
# Saved frame: all_frames/frame_20068.jpg
# Saved frame: all_frames/frame_20097.jpg
# Saved frame: all_frames/frame_20126.jpg
# Saved frame: all_frames/frame_20155.jpg
# Saved frame: all_frames/frame_20184.jpg
# Saved frame: all_frames/frame_20213.jpg
# Saved frame: all_frames/frame_20242.jpg
# Saved frame: all_frames/frame_20271.jpg
# Saved frame: all_frames/frame_20300.jpg
# Saved frame: all_frames/frame_20329.jpg
# Saved frame: all_frames/frame_20358.jpg
# Saved frame: all_frames/frame_20387.jpg
# Saved frame: all_frames/frame_20416.jpg
# Saved frame: all_frames/frame_20445.jpg
# Saved frame: all_frames/frame_20474.jpg
# Saved frame: all_frames/frame_20503.jpg
# Saved frame: all_frames/frame_20532.jpg
# Saved frame: all_frames/frame_20561.jpg
# Saved frame: all_frames/frame_20590.jpg
# Saved frame: all_frames/frame_20619.jpg
# Saved frame: all_frames/frame_20648.jpg
# Saved frame: all_frames/frame_20677.jpg
# Saved frame: all_frames/frame_20706.jpg
# Saved frame: all_frames/frame_20735.jpg
# Saved frame: all_frames/frame_20764.jpg
# Saved frame: all_frames/frame_20793.jpg
# Saved frame: all_frames/frame_20822.jpg
# Saved frame: all_frames/frame_20851.jpg
# Saved frame: all_frames/frame_20880.jpg
# Saved frame: all_frames/frame_20909.jpg
# Saved frame: all_frames/frame_20938.jpg
# Saved frame: all_frames/frame_20967.jpg
# Saved frame: all_frames/frame_20996.jpg
# Saved frame: all_frames/frame_21025.jpg
# Saved frame: all_frames/frame_21054.jpg
# Saved frame: all_frames/frame_21083.jpg
# Saved frame: all_frames/frame_21112.jpg
# Saved frame: all_frames/frame_21141.jpg
# Saved frame: all_frames/frame_21170.jpg
# Saved frame: all_frames/frame_21199.jpg
# Saved frame: all_frames/frame_21228.jpg
# Saved frame: all_frames/frame_21257.jpg
# Saved frame: all_frames/frame_21286.jpg
# Saved frame: all_frames/frame_21315.jpg
# Saved frame: all_frames/frame_21344.jpg
# Saved frame: all_frames/frame_21373.jpg
# Saved frame: all_frames/frame_21402.jpg
# Saved frame: all_frames/frame_21431.jpg
# Saved frame: all_frames/frame_21460.jpg
# Saved frame: all_frames/frame_21489.jpg
# Saved frame: all_frames/frame_21518.jpg
# Saved frame: all_frames/frame_21547.jpg
# Saved frame: all_frames/frame_21576.jpg
# Saved frame: all_frames/frame_21605.jpg
# Saved frame: all_frames/frame_21634.jpg
# Saved frame: all_frames/frame_21663.jpg
# Saved frame: all_frames/frame_21692.jpg
# Saved frame: all_frames/frame_21721.jpg
# Saved frame: all_frames/frame_21750.jpg
# Saved frame: all_frames/frame_21779.jpg
# Saved frame: all_frames/frame_21808.jpg
# Saved frame: all_frames/frame_21837.jpg
# Saved frame: all_frames/frame_21866.jpg
# Saved frame: all_frames/frame_21895.jpg
# Saved frame: all_frames/frame_21924.jpg
# Saved frame: all_frames/frame_21953.jpg
# Saved frame: all_frames/frame_21982.jpg
# Saved frame: all_frames/frame_22011.jpg
# Saved frame: all_frames/frame_22040.jpg
# Saved frame: all_frames/frame_22069.jpg
# Saved frame: all_frames/frame_22098.jpg
# Saved frame: all_frames/frame_22127.jpg
# Saved frame: all_frames/frame_22156.jpg
# Saved frame: all_frames/frame_22185.jpg
# Saved frame: all_frames/frame_22214.jpg
# Saved frame: all_frames/frame_22243.jpg
# Saved frame: all_frames/frame_22272.jpg
# Saved frame: all_frames/frame_22301.jpg
# Saved frame: all_frames/frame_22330.jpg
# Saved frame: all_frames/frame_22359.jpg
# Saved frame: all_frames/frame_22388.jpg
# Saved frame: all_frames/frame_22417.jpg
# Saved frame: all_frames/frame_22446.jpg
# Saved frame: all_frames/frame_22475.jpg
# Saved frame: all_frames/frame_22504.jpg
# Saved frame: all_frames/frame_22533.jpg
# Saved frame: all_frames/frame_22562.jpg
# Saved frame: all_frames/frame_22591.jpg
# Saved frame: all_frames/frame_22620.jpg
# Saved frame: all_frames/frame_22649.jpg
# Saved frame: all_frames/frame_22678.jpg
# Saved frame: all_frames/frame_22707.jpg
# Saved frame: all_frames/frame_22736.jpg
# Saved frame: all_frames/frame_22765.jpg
# Saved frame: all_frames/frame_22794.jpg
# Saved frame: all_frames/frame_22823.jpg
# Saved frame: all_frames/frame_22852.jpg
# Saved frame: all_frames/frame_22881.jpg
# Saved frame: all_frames/frame_22910.jpg
# Saved frame: all_frames/frame_22939.jpg
# Saved frame: all_frames/frame_22968.jpg
# Saved frame: all_frames/frame_22997.jpg
# Saved frame: all_frames/frame_23026.jpg
# Saved frame: all_frames/frame_23055.jpg
# Saved frame: all_frames/frame_23084.jpg
# Saved frame: all_frames/frame_23113.jpg
# Saved frame: all_frames/frame_23142.jpg
# Saved frame: all_frames/frame_23171.jpg
# Saved frame: all_frames/frame_23200.jpg
# Saved frame: all_frames/frame_23229.jpg
# Saved frame: all_frames/frame_23258.jpg
# Saved frame: all_frames/frame_23287.jpg
# Saved frame: all_frames/frame_23316.jpg
# Saved frame: all_frames/frame_23345.jpg
# Saved frame: all_frames/frame_23374.jpg
# Saved frame: all_frames/frame_23403.jpg
# Saved frame: all_frames/frame_23432.jpg
# Saved frame: all_frames/frame_23461.jpg
# Saved frame: all_frames/frame_23490.jpg
# Saved frame: all_frames/frame_23519.jpg
# Saved frame: all_frames/frame_23548.jpg
# Saved frame: all_frames/frame_23577.jpg
# Saved frame: all_frames/frame_23606.jpg
# Saved frame: all_frames/frame_23635.jpg
# Saved frame: all_frames/frame_23664.jpg
# Saved frame: all_frames/frame_23693.jpg
# Saved frame: all_frames/frame_23722.jpg
# Saved frame: all_frames/frame_23751.jpg
# Saved frame: all_frames/frame_23780.jpg
# Saved frame: all_frames/frame_23809.jpg
# Saved frame: all_frames/frame_23838.jpg
# Saved frame: all_frames/frame_23867.jpg
# Saved frame: all_frames/frame_23896.jpg
# Saved frame: all_frames/frame_23925.jpg
# Saved frame: all_frames/frame_23954.jpg
# Saved frame: all_frames/frame_23983.jpg
# Saved frame: all_frames/frame_24012.jpg
# Saved frame: all_frames/frame_24041.jpg
# Saved frame: all_frames/frame_24070.jpg
# Saved frame: all_frames/frame_24099.jpg
# Saved frame: all_frames/frame_24128.jpg
# Saved frame: all_frames/frame_24157.jpg
# Saved frame: all_frames/frame_24186.jpg
# Saved frame: all_frames/frame_24215.jpg
# Saved frame: all_frames/frame_24244.jpg
# Saved frame: all_frames/frame_24273.jpg
# Saved frame: all_frames/frame_24302.jpg
# Saved frame: all_frames/frame_24331.jpg
# Saved frame: all_frames/frame_24360.jpg
# Saved frame: all_frames/frame_24389.jpg
# Saved frame: all_frames/frame_24418.jpg
# Saved frame: all_frames/frame_24447.jpg
# Saved frame: all_frames/frame_24476.jpg
# Saved frame: all_frames/frame_24505.jpg
# Saved frame: all_frames/frame_24534.jpg
# Saved frame: all_frames/frame_24563.jpg
# Saved frame: all_frames/frame_24592.jpg
# Saved frame: all_frames/frame_24621.jpg
# Saved frame: all_frames/frame_24650.jpg
# Saved frame: all_frames/frame_24679.jpg
# Saved frame: all_frames/frame_24708.jpg
# Saved frame: all_frames/frame_24737.jpg
# Saved frame: all_frames/frame_24766.jpg
# Saved frame: all_frames/frame_24795.jpg
# All frames saved to: all_frames
# Total frames extracted: 856

# %% [markdown]
# # 자막 추출
# - google-vision-api 사용

# %%
import os
import cv2
from google.cloud import vision

# 환경변수 설정
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/content/image-443101-514bb45e53e7.json"
client = vision.ImageAnnotatorClient()

# 디렉토리 설정
all_frame_dir = "/content/all_frames"
output_dir = "/content/output_texts"
processed_frames_dir = "/content/processed_frames"

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

output_text_file = os.path.join(output_dir, "extracted_texts.txt")

image_files = [f for f in os.listdir(all_frame_dir) if f.endswith(".jpg")]
image_files.sort()

with open(output_text_file, "w") as f:
    f.write("### Vision API 추출 결과 ###\n\n")

for image_file in image_files:
    image_path = os.path.join(all_frame_dir, image_file)
    print(f"Processing: {image_path}")

    try:
        # 이미지 읽기
        image = cv2.imread(image_path)

        # 이미지 전처리
        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        processed_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

        # 전처리된 이미지 저장
        processed_image_path = os.path.join(processed_frames_dir, image_file)
        cv2.imwrite(processed_image_path, processed_image)

        # OpenCV로 이미지 인코딩
        success, encoded_image = cv2.imencode(".jpg", processed_image)
        if not success:
            print(f"Failed to encode image: {image_file}")
            continue

        # Vision API 요청 준비 및 텍스트 추출
        content = encoded_image.tobytes()
        image_vision = vision.Image(content=content)
        response = client.text_detection(image=image_vision)

        texts = response.text_annotations
        extracted_text = texts[0].description if texts else "No text detected."
        print(f"Extracted text:\n{extracted_text}")

        # 개별 텍스트 파일 저장 및 통합 텍스트 파일에 추가
        individual_text_file = os.path.join(output_dir, f"{image_file.split('.')[0]}.txt")
        with open(individual_text_file, "w") as f:
            f.write(extracted_text)

        with open(output_text_file, "a") as f:
            f.write(f"### {image_file} ###\n{extracted_text}\n\n")

    except Exception as e:
        print(f"Error processing {image_file}: {str(e)}")
        continue

print(f"All text extracted and saved to {output_text_file}.")
# Out:
# Processing: /content/all_frames/frame_00000.jpg
# Extracted text:
# 7월 26일
# 먹태는 유치원가고 유준이는 낮잠자는중
# Processing: /content/all_frames/frame_00029.jpg
# Extracted text:
# 7월 26일
# 먹태는 유치원 가고 유준이는 낮잠자는중
# Processing: /content/all_frames/frame_00058.jpg
# Extracted text:
# 7월 26일
# 먹태는 유치원 가고 유준이는 낮잠자는 중
# Processing: /content/all_frames/frame_00087.jpg
# Extracted text:
# (아빠 온지도 모르고 세상 편하게 자는 중 ㅋㅋ)
# Processing: /content/all_frames/frame_00116.jpg
# Extracted text:
# (아빠 온지도 모르고 세상 편하게 자는중ㅋㅋ
# Processing: /content/all_frames/frame_00145.jpg
# Extracted text:
# (아빠 온지도 모르고 세상 편하게 자는중ㅋㅋ
# Processing: /content/all_frames/frame_00174.jpg
# Extracted text:
# 일어날때가 됐다고 생각중이었는데 바로 잠깼어요ㅋㅋ
# Processing: /content/all_frames/frame_00203.jpg
# Extracted text:
# 일어날때가 됐다고 생각중이었는데 바로 잠깼어요 ㅋㅋ
# Processing: /content/all_frames/frame_00232.jpg
# Extracted text:
# 일어날 때가 됐다고 생각중이었는데 바로 잠깼어요 ㅋㅋ
# Processing: /content/all_frames/frame_00261.jpg
# Extracted text:
# 일어날 때가 됐다고 생각중이었는데 바로 잠깼어요ㅋㅋ
# Processing: /content/all_frames/frame_00290.jpg
# Extracted text:
# 일어날 때가 됐다고 생각중이었는데 바로 잠깼어요ㅋㅋ
# Processing: /content/all_frames/frame_00319.jpg
# Extracted text:
# 하
# 품
# Processing: /content/all_frames/frame_00348.jpg
# Extracted text:
# 하
# 품
# Processing: /content/all_frames/frame_00377.jpg
# Extracted text:
# 하
# 품
# Processing: /content/all_frames/frame_00406.jpg
# Extracted text:
# 하
# 품
# Processing: /content/all_frames/frame_00435.jpg
# Extracted text:
# 드디어 아빠 발견
# Processing: /content/all_frames/frame_00464.jpg
# Extracted text:
# 드디어 아빠 발견
# Processing: /content/all_frames/frame_00493.jpg
# Extracted text:
# 잘 잤어?
# Processing: /content/all_frames/frame_00522.jpg
# Extracted text:
# (비몽사몽..)
# Processing: /content/all_frames/frame_00551.jpg
# Extracted text:
# (비몽사몽..)
# Processing: /content/all_frames/frame_00580.jpg
# Extracted text:
# (귀여워 죽겠다 ㅋㅋㅋㅋ)
# Processing: /content/all_frames/frame_00609.jpg
# Extracted text:
# (귀여워 죽겠다ㅋㅋㅋㅋ)
# Processing: /content/all_frames/frame_00638.jpg
# Extracted text:
# (귀여워 죽겠다ㅋㅋㅋㅋ)
# Processing: /content/all_frames/frame_00667.jpg
# Extracted text:
# 잘 잤어요?
# Processing: /content/all_frames/frame_00696.jpg
# Extracted text:
# (하품으로 대답중)
# Processing: /content/all_frames/frame_00725.jpg
# Extracted text:
# (하품으로 대답중)
# Processing: /content/all_frames/frame_00754.jpg
# Extracted text:
# (하품으로 대답중)
# Processing: /content/all_frames/frame_00783.jpg
# Extracted text:
# (실수로 화질 구린 걸로 설정..)
# 머리에 새로 산 카메라 달고찍어봤어요 ㅎㅎㅎ
# Processing: /content/all_frames/frame_00812.jpg
# Extracted text:
# (실수로 화질 구린 걸로 설정..
# 머리에 새로 산 카메라 달고 찍어봤어요 ㅎㅎㅎ
# Processing: /content/all_frames/frame_00841.jpg
# Extracted text:
# (실수로 화질 구린 걸로 설정..)
# 머리에 새로 산 카메라 달고 찍어봤어요 ㅎㅎ
# Processing: /content/all_frames/frame_00870.jpg
# Extracted text:
# (실수로 화질 구린 걸로 설정..)
# 머리에 새로 산 카메라 달고 찍어봤어요 ㅎㅎㅎ
# Processing: /content/all_frames/frame_00899.jpg
# Extracted text:
# (실수로 화질 구린 걸로 설정..)
# 머리에 새로 산 카메라 달고찍어봤어요 ㅎㅎㅎ
# Processing: /content/all_frames/frame_00928.jpg
# Extracted text:
# (실수로 화질 구린 걸로 설정..
# 머리에 새로산 카메라 달고찍어봤어요 ㅎㅎ
# Processing: /content/all_frames/frame_00957.jpg
# Extracted text:
# Rote
# (배고파서 급짜증)
# Processing: /content/all_frames/frame_00986.jpg
# Extracted text:
# HR
# Processing: /content/all_frames/frame_01015.jpg
# Extracted text:
# (배고파티를 짜증)
# Processing: /content/all_frames/frame_01044.jpg
# Extracted text:
# (바코파서 급쨔증)
# Processing: /content/all_frames/frame_01073.jpg
# Extracted text:
# ?
# いく
# Processing: /content/all_frames/frame_01102.jpg
# Extracted text:
# 자 밥부터 먹어볼까요?
# Processing: /content/all_frames/frame_01131.jpg
# Extracted text:
# 우리 유준이?
# Processing: /content/all_frames/frame_01160.jpg
# Extracted text:
# 셀프 수유쿠션 장착해주시고
# Processing: /content/all_frames/frame_01189.jpg
# Extracted text:
# 셀프 수유쿠션 장착해주시고
# Processing: /content/all_frames/frame_01218.jpg
# Extracted text:
# 셀프 수유쿠션 장착해주시고
# Processing: /content/all_frames/frame_01247.jpg
# Extracted text:
# 분유 보고 벌써 입 벌리기 시작 ㅋㅋ
# Processing: /content/all_frames/frame_01276.jpg
# Extracted text:
# 분유 보고 벌써 입 벌리기 시작 ㅋㅋ
# Processing: /content/all_frames/frame_01305.jpg
# Extracted text:
# 분유 보고 벌써 입 벌리기 시작 ㅋㅋ
# Processing: /content/all_frames/frame_01334.jpg
# Extracted text:
# 입벌려 분유 들어간다!
# Processing: /content/all_frames/frame_01363.jpg
# Extracted text:
# 입벌려 분유 들어간다!
# Processing: /content/all_frames/frame_01392.jpg
# Extracted text:
# 입벌려 분유 들어간다!
# Processing: /content/all_frames/frame_01421.jpg
# Extracted text:
# 맛있게 먹는 동안 어플에 밥 먹은 시간 기록 중
# Processing: /content/all_frames/frame_01450.jpg
# Extracted text:
# ,
# 맛있게 먹는 동안 어플에 밥 먹은 시간 기록 중
# Processing: /content/all_frames/frame_01479.jpg
# Extracted text:
# I
# 맛있게 먹는 동안 어플에 밥 먹은 시간 기록 중
# Processing: /content/all_frames/frame_01508.jpg
# Extracted text:
# I
# 맛있게 먹는 동안 어플에 밥 먹은 시간 기록 중
# Processing: /content/all_frames/frame_01537.jpg
# Extracted text:
# 아빠 손은 왜 꼭 잡고 먹는 거야? ㅎㅎ
# Processing: /content/all_frames/frame_01566.jpg
# Extracted text:
# 아빠 손은 왜 꼭 잡고 먹는 거야? ㅎㅎ
# ns
# Processing: /content/all_frames/frame_01595.jpg
# Extracted text:
# 아빠 손은 왜 꼭 잡고 먹는 거야? ㅎㅎ
# uns
# Processing: /content/all_frames/frame_01624.jpg
# Extracted text:
# 이렇게 또 먹을 때 딴짓하지!!
# Processing: /content/all_frames/frame_01653.jpg
# Extracted text:
# 이렇게 또 먹을 때 딴짓하지!!
# Processing: /content/all_frames/frame_01682.jpg
# Extracted text:
# 또 뱉어내요~?
# Processing: /content/all_frames/frame_01711.jpg
# Extracted text:
# 또 뱉어내요~?
# Processing: /content/all_frames/frame_01740.jpg
# Extracted text:
# 어~? 이렇게 또 밀어내~?
# Processing: /content/all_frames/frame_01769.jpg
# Extracted text:
# 어~? 이렇게 또 밀어나~?
# Processing: /content/all_frames/frame_01798.jpg
# Extracted text:
# 어~? 이렇게 또 밀어내~?
# Processing: /content/all_frames/frame_01827.jpg
# Extracted text:
# (아니 그건 아니고.)
# Processing: /content/all_frames/frame_01856.jpg
# Extracted text:
# (아니 그건 아니고)
# Processing: /content/all_frames/frame_01885.jpg
# Extracted text:
# 처음 보는 카메라 신기해요?
# Processing: /content/all_frames/frame_01914.jpg
# Extracted text:
# 처음 보는 카메라 신기해요?
# Processing: /content/all_frames/frame_01943.jpg
# Extracted text:
# 이게 카메라..?
# Processing: /content/all_frames/frame_01972.jpg
# Extracted text:
# (이게 카메라..? ㅇ
# Processing: /content/all_frames/frame_02001.jpg
# Extracted text:
# (이게 카메라..?)
# Processing: /content/all_frames/frame_02030.jpg
# Extracted text:
# 새로 산 카메라 덕분에 쥬디바분들 1인칭 조땡 시점 경험
# Processing: /content/all_frames/frame_02059.jpg
# Extracted text:
# 새로산 카메라 덕분에 쥬디바분들 1인칭 조땡 시점 경험(
# Processing: /content/all_frames/frame_02088.jpg
# Extracted text:
# 새로산 카메라 덕분에 쥬디바분들 1인칭 조땡 시점 경험(
# Processing: /content/all_frames/frame_02117.jpg
# Extracted text:
# 새로산 카메라 덕분에 쥬디바분들 1인칭 조땡 시점 경험(
# Processing: /content/all_frames/frame_02146.jpg
# Extracted text:
# 새로 산 카메라 덕분에 쥬디바분들 1인칭 조땡 시점 경험
# Processing: /content/all_frames/frame_02175.jpg
# Extracted text:
# 새로산 카메라 덕분에 쥬디바분들 1인칭 조땡 시점 경험
# Processing: /content/all_frames/frame_02204.jpg
# Extracted text:
# 새로 산 카메라 덕분에 쥬디바분들 1인칭 조땡 시점 경험
# Processing: /content/all_frames/frame_02233.jpg
# Extracted text:
# 새로 산 카메라 덕분에 쥬디바분들 1인칭 조땡 시점 경험
# Processing: /content/all_frames/frame_02262.jpg
# Extracted text:
# 새로 산 카메라 덕분에 쥬디바분들 1인칭 조땡 시점 경험
# Processing: /content/all_frames/frame_02291.jpg
# Extracted text:
# 새로산 카메라 덕분에 쥬디바분들 1인칭 조땡 시점 경험(
# Processing: /content/all_frames/frame_02320.jpg
# Extracted text:
# 초록&단비&성아
# 오늘은 조땡 동기들 놀러오는 날!
# Processing: /content/all_frames/frame_02349.jpg
# Extracted text:
# 초록&단비&성아
# 오늘은 조땡 동기들 놀러오는 날!
# Processing: /content/all_frames/frame_02378.jpg
# Extracted text:
# 9
# Happy dan
# HOPE
# 초록&단비&성아
# 오늘은 조땡동기들 놀러오는날!
# Processing: /content/all_frames/frame_02407.jpg
# Extracted text:
# 이모들을 맞이하는 밀짚모자 유준 ㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_02436.jpg
# Extracted text:
# 나름 이
# Processing: /content/all_frames/frame_02465.jpg
# Extracted text:
# 이모들을 맞이하는 밀짚모자 유준 ㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_02494.jpg
# Extracted text:
# 이모들을 맞이하는 밀짚모자 유준 ㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_02523.jpg
# Extracted text:
# 이모들을 맞이하는 밀짚모자 유준 ㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_02552.jpg
# Extracted text:
# DO
# 유준이 선물이랑 편지 바리바리 싸온 고마운 이모들:
# Processing: /content/all_frames/frame_02581.jpg
# Extracted text:
# Nike
# 3-Piece Set
# DO
# 유준이 선물이랑 편지 바리바리 싸온 고마운 이모들
# Processing: /content/all_frames/frame_02610.jpg
# Extracted text:
# 유준이 선물이랑편지 바리바리 싸온 고마운 이모들
# Processing: /content/all_frames/frame_02639.jpg
# Extracted text:
# 유준이 선물이랑편지 바리바리 싸온 고마운 이모들:
# Processing: /content/all_frames/frame_02668.jpg
# Extracted text:
# (유준이는 바로 이모품으로)
# Processing: /content/all_frames/frame_02697.jpg
# Extracted text:
# (유준이는 바로 이모품으로)
# Processing: /content/all_frames/frame_02726.jpg
# Extracted text:
# (유준이는 바로 이모품으로)
# Processing: /content/all_frames/frame_02755.jpg
# Extracted text:
# POST CARD
# 유준이가 더 컸을 때 입기 딱 좋은 옷들
# Processing: /content/all_frames/frame_02784.jpg
# Extracted text:
# POST CARD
# 유준이가 더 컸을 때 입기 딱 좋은 옷들
# Processing: /content/all_frames/frame_02813.jpg
# Extracted text:
# 유준이가 더 컸을 때 입기 딱 좋은 옷들
# Processing: /content/all_frames/frame_02842.jpg
# Extracted text:
# 유준이가 더 컸을 때 입기 딱 좋은 옷들
# CELLENCE
# Processing: /content/all_frames/frame_02871.jpg
# Extracted text:
# 유준이가 더 컸을 때 입기 딱 좋은 옷들
# Processing: /content/all_frames/frame_02900.jpg
# Extracted text:
# 유준이가 더 컸을 때 입기 딱 좋은 옷들
# Processing: /content/all_frames/frame_02929.jpg
# Extracted text:
# 지금 입을 수 있는 청멜빵이랑 청모자 ㅋㅋ
# Processing: /content/all_frames/frame_02958.jpg
# Extracted text:
# 지금 입을 수 있는 청멜빵이랑 청모자 크크
# Processing: /content/all_frames/frame_02987.jpg
# Extracted text:
# 지금 입을 수 있는 청멜빵이랑 청모자 ㅋㅋ
# Processing: /content/all_frames/frame_03016.jpg
# Extracted text:
# 80
# 지금 입을 수 있는 청멜빵이랑 청모자 ㅋㅋ
# Processing: /content/all_frames/frame_03045.jpg
# Extracted text:
# 지금 입을 수 있는 청멜빵이랑 청모자 ㅋㅋ
# Processing: /content/all_frames/frame_03074.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_03103.jpg
# Extracted text:
# 퍼스널 컬러가 청이세요
# Processing: /content/all_frames/frame_03132.jpg
# Extracted text:
# 퍼스널 컬러가 청이세요
# Processing: /content/all_frames/frame_03161.jpg
# Extracted text:
# 퍼스널 컬러가 청이세요
# Processing: /content/all_frames/frame_03190.jpg
# Extracted text:
# 제 2의 섹시 농부가 될거 같은 청멜빵ㅋㅋ
# Processing: /content/all_frames/frame_03219.jpg
# Extracted text:
# 제 2의 섹시 농부가 될 거 같은 청멜빵ㅋㅋ
# Processing: /content/all_frames/frame_03248.jpg
# Extracted text:
# 제 2의 섹시 농부가 될 거 같은 청멜빵ㅋ
# Processing: /content/all_frames/frame_03277.jpg
# Extracted text:
# 제 2의 섹시 농부가 될 거 같은 청멜빵ㅋ
# Processing: /content/all_frames/frame_03306.jpg
# Extracted text:
# 유준이 기분 진짜 좋아보이는데~?
# Processing: /content/all_frames/frame_03335.jpg
# Extracted text:
# (이모들 와서 너무 좋아!)
# Processing: /content/all_frames/frame_03364.jpg
# Extracted text:
# (이모들 와서 너무 좋아!!
# Processing: /content/all_frames/frame_03393.jpg
# Extracted text:
# (이모들 와서 너무 좋아!)
# Processing: /content/all_frames/frame_03422.jpg
# Extracted text:
# VLOG
# 이 언니게
# 혜주X성아 만나다
# 20:48
# 남편 소개팅해준 큐피트 만나고왔습니다
# 조회수25만회 1년 전
# (요 영상에 나오셨던!)
# 성아 어머님이 주신 턱받이랑 양말선물 ㅠㅠ 감사합니다♡
# Processing: /content/all_frames/frame_03451.jpg
# Extracted text:
# 혜주X 성아 만나다
# 남편 소개팅해준 큐피트 만나고왔습니다
# 조회수25만회 1년 전
# (요 영상에 나오셨던!)
# 성아 어머님이 주신 턱받이랑 양말선물 ㅠㅠ 감사합니다♡
# 20:48
# Processing: /content/all_frames/frame_03480.jpg
# Extracted text:
# 혜주X 성아 만나다
# 남편 소개팅해준 큐피트 만나고왔습니다
# 조회수25만회 1년 전
# (요 영상에 나오셨던!)
# 성아 어머님이 주신 턱받이랑 양말선물ㅠㅠ 감사합니다♡
# 20:48
# Processing: /content/all_frames/frame_03509.jpg
# Extracted text:
# VLOC
# 이 언니 웃겨
# 20:48
# 혜주X성아 만나다
# 남편 소개팅해준 큐피트 만나고왔습니다
# 조회수25만회 1년 전
# (요 영상에 나오셨던!)
# 성아 어머님이 주신 턱받이랑 양말선물 ㅠㅠ 감사합니다♡
# Processing: /content/all_frames/frame_03538.jpg
# Extracted text:
# 혜주X성아 만나다
# 남편 소개팅해준 큐피트 만나고왔습니다
# 조회수25만회 1년 전
# (요 영상에 나오셨던!)
# 성아 어머님이 주신 턱받이랑 양말선물ㅠㅠ감사합니다♡
# 20:48
# Processing: /content/all_frames/frame_03567.jpg
# Extracted text:
# VLOG
# 이언니 웃겨
# 20:48
# 혜주X성아 만나다
# 남편 소개팅해준 큐피트 만나고왔습니다
# 조회수25만회 1년 전
# (요 영상에 나오셨던!)
# 성아 어머님이 주신 턱받이랑 양말선물 ㅠㅠ 감사합니다♡
# Processing: /content/all_frames/frame_03596.jpg
# Extracted text:
# 조팽이 입고 싶을 정도로(?) 조땡 스타일인
# Processing: /content/all_frames/frame_03625.jpg
# Extracted text:
# 조땡이 입고 싶을 정도로(?) 조팽 스타일인
# Processing: /content/all_frames/frame_03654.jpg
# Extracted text:
# 나이키 비니&옷&양말 세트 ㅋㅋ
# Processing: /content/all_frames/frame_03683.jpg
# Extracted text:
# 나이키 비니&옷&양말 세트 ㅋㅋ
# Processing: /content/all_frames/frame_03712.jpg
# Extracted text:
# 나이키 비니&옷&양말 세트 ㅋㅋ
# Processing: /content/all_frames/frame_03741.jpg
# Extracted text:
# (뿌에에엥)
# Processing: /content/all_frames/frame_03770.jpg
# Extracted text:
# (일동 사과)
# Processing: /content/all_frames/frame_03799.jpg
# Extracted text:
# (일동 사과)
# Processing: /content/all_frames/frame_03828.jpg
# Extracted text:
# 거슬리지 않게 조용히 해주세요
# Processing: /content/all_frames/frame_03857.jpg
# Extracted text:
# 8
# 거슬리지 않게 조용히 해주세요 ㅅ
# Processing: /content/all_frames/frame_03886.jpg
# Extracted text:
# 랩퍼 힙이 등장
# Processing: /content/all_frames/frame_03915.jpg
# Extracted text:
# 랩퍼 합쮸이 등장
# Processing: /content/all_frames/frame_03944.jpg
# Extracted text:
# 랩퍼 힙쮸이 등장
# Processing: /content/all_frames/frame_03973.jpg
# Extracted text:
# 랩퍼 힙쮸이 등장
# Processing: /content/all_frames/frame_04002.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_04031.jpg
# Extracted text:
# 힙함을 +5 획득하셨습니다
# Processing: /content/all_frames/frame_04060.jpg
# Extracted text:
# 힙함을 획득하셨습니다
# Processing: /content/all_frames/frame_04089.jpg
# Extracted text:
# 힙함을 5 획득하셨습니다
# Processing: /content/all_frames/frame_04118.jpg
# Extracted text:
# 손님 맞이용이자 우리 부부 최애 해물갈비찜 ㅋㅋ
# Processing: /content/all_frames/frame_04147.jpg
# Extracted text:
# 손님맞이용이자 우리 부부 최애 해물갈비찜 ㅋㅋ
# Processing: /content/all_frames/frame_04176.jpg
# Extracted text:
# 손님맞이용이자 우리 부부 최애 해물갈비찜 ㅋㅋ
# Processing: /content/all_frames/frame_04205.jpg
# Extracted text:
# 수유 중인 유준이한테 눈을 못 떼는 이모야들 ㅋㅋ
# Processing: /content/all_frames/frame_04234.jpg
# Extracted text:
# 수유 중인 유준이한테 눈을 못 떼는 이모야들 ㅋㅋㅋ
# Processing: /content/all_frames/frame_04263.jpg
# Extracted text:
# 수유 중인 유준이한테 눈을 못 떼는 이모야 ㅋㅋ
# Processing: /content/all_frames/frame_04292.jpg
# Extracted text:
# 수유 중인 유준이한테 눈을 못 떼는 이모야들 ㅋㅋ
# Processing: /content/all_frames/frame_04321.jpg
# Extracted text:
# 수유 중인 유준이한테 눈을 못 떼는 이모야들 ㅋㅋ
# Processing: /content/all_frames/frame_04350.jpg
# Extracted text:
# 수유 중인 유준이한테 눈을 못 떼는 이모야들 ㅋㅋ
# Processing: /content/all_frames/frame_04379.jpg
# Extracted text:
# 여보는 좀 편한가?
# Processing: /content/all_frames/frame_04408.jpg
# Extracted text:
# 1
# 여보는 좀 편한가?
# Processing: /content/all_frames/frame_04437.jpg
# Extracted text:
# 집에.. 집에 손님 오니까 좋다♥"
# 우린 커피 좀 먹고 있자 ㅎㅎㅎ
# Processing: /content/all_frames/frame_04466.jpg
# Extracted text:
# 집에.. 집에 손님 오니까 좋다♥
# 우린 커피 좀 먹고 있자 ㅎㅎㅎ
# Processing: /content/all_frames/frame_04495.jpg
# Extracted text:
# 1
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_04524.jpg
# Extracted text:
# 1
# COMPON
# FFFㅋㅋㅋㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_04553.jpg
# Extracted text:
# 이때다 싶어서 여유 즐기기
# Processing: /content/all_frames/frame_04582.jpg
# Extracted text:
# IPOS
# 이때다 싶어서 여유 즐기기
# Processing: /content/all_frames/frame_04611.jpg
# Extracted text:
# 이때다 싶어서 여유 즐기기
# Processing: /content/all_frames/frame_04640.jpg
# Extracted text:
# LON DA
# Happy greenday
# 사실 초록이랑 단비 생일이어서 파티도 합니다!
# Processing: /content/all_frames/frame_04669.jpg
# Extracted text:
# 사실 초록이랑 단비 생일이어서 파티도 합니다!
# Processing: /content/all_frames/frame_04698.jpg
# Extracted text:
# 사실 초록이랑 단비 생일이어서 파티도 합니다!!
# Processing: /content/all_frames/frame_04727.jpg
# Extracted text:
# 자유준아~?
# Processing: /content/all_frames/frame_04756.jpg
# Extracted text:
# 자유준아~?
# Processing: /content/all_frames/frame_04785.jpg
# Extracted text:
# 이모들 생일 파티를 시작하겠습니데이~!
# Processing: /content/all_frames/frame_04814.jpg
# Extracted text:
# 이모들 생일 파티를 시작하겠습니데이~!
# Processing: /content/all_frames/frame_04843.jpg
# Extracted text:
# 이모들 생일 파티를 시작하겠습니데이~!
# Processing: /content/all_frames/frame_04872.jpg
# Extracted text:
# Happy dan
# 생일 축하합니다.
# Processing: /content/all_frames/frame_04901.jpg
# Extracted text:
# Happy darbay
# '생일 축하합니다!
# Processing: /content/all_frames/frame_04930.jpg
# Extracted text:
# 불을 붙여줘야 되는 거 아니야...?
# reen
# Processing: /content/all_frames/frame_04959.jpg
# Extracted text:
# 불을 붙여줘야 되는 거 아니야..?
# Happy gre
# Processing: /content/all_frames/frame_04988.jpg
# Extracted text:
# Happy dart
# 찬밥 신세인 오늘의 주인공들...
# Processing: /content/all_frames/frame_05017.jpg
# Extracted text:
# 찬밥신세인 오늘의 주인공들..
# Processing: /content/all_frames/frame_05046.jpg
# Extracted text:
# 찬밥 신세인 오늘의 주인공들..
# Processing: /content/all_frames/frame_05075.jpg
# Extracted text:
# Happy darbey
# Happyreenday
# 생일 축하합니다!
# Processing: /content/all_frames/frame_05104.jpg
# Extracted text:
# Happy fav
# 생일 축하합니다
# Processing: /content/all_frames/frame_05133.jpg
# Extracted text:
# Happy danbeeday
# Happend
# 생일 축하합니다!
# Processing: /content/all_frames/frame_05162.jpg
# Extracted text:
# 생일 축하합니다!
# Processing: /content/all_frames/frame_05191.jpg
# Extracted text:
# Happy danbeeday
# Hafcenday
# 사랑하는 초록&단비
# Processing: /content/all_frames/frame_05220.jpg
# Extracted text:
# enday
# 사랑하는초록&단비
# Processing: /content/all_frames/frame_05249.jpg
# Extracted text:
# Happy darleeday
# 생일축하합니다!
# Processing: /content/all_frames/frame_05278.jpg
# Extracted text:
# Happy durheeday
# Harpreenday
# 생일 축하합니다!
# Processing: /content/all_frames/frame_05307.jpg
# Extracted text:
# Har
# 오랜만에 다 같이 기념사진도 많이 찍었어요 ㅎㅎ
# Processing: /content/all_frames/frame_05336.jpg
# Extracted text:
# H
# 오랜만에 다같이 기념사진도 많이 찍었어요 ㅎㅎㅎㅎ
# Processing: /content/all_frames/frame_05365.jpg
# Extracted text:
# Ha
# 오랜만에 다 같이 기념사진도 많이 찍었어요 ㅎㅎ
# Processing: /content/all_frames/frame_05394.jpg
# Extracted text:
# Happ
# 오랜만에 다같이 기념사진도 많이 찍었어요 ㅎㅎㅎ
# Processing: /content/all_frames/frame_05423.jpg
# Extracted text:
# Happy
# 오랜만에 다같이 기념사진도 많이 찍었어요 ㅎㅎ
# Processing: /content/all_frames/frame_05452.jpg
# Extracted text:
# JOURNE
# 오랜만에 다 같이 기념사진도 많이 찍었어요 ㅎㅎ
# Processing: /content/all_frames/frame_05481.jpg
# Extracted text:
# JOURNEY
# 오랜만에 다 같이 기념사진도 많이 찍었어요 ㅎㅎ
# Processing: /content/all_frames/frame_05510.jpg
# Extracted text:
# OURNEY
# 오랜만에 다같이 기념사진도 많이 찍었어요 ㅎㅎ
# Processing: /content/all_frames/frame_05539.jpg
# Extracted text:
# ORNEY
# 오랜만에 다같이 기념사진도 많이 찍었어요 ㅎㅎㅎ
# Processing: /content/all_frames/frame_05568.jpg
# Extracted text:
# JOURNEY
# 오랜만에 다 같이 기념사진도 많이 찍었어요 ㅎㅎㅎ
# Processing: /content/all_frames/frame_05597.jpg
# Extracted text:
# Happy greenday
# (다들 항상 건강하고 행복하세요)
# Processing: /content/all_frames/frame_05626.jpg
# Extracted text:
# Happy Senday
# (다들 항상 건강하고 행복하세요)
# Processing: /content/all_frames/frame_05655.jpg
# Extracted text:
# Happy greenday
# (다들 항상 건강하고 행복하세요)
# Processing: /content/all_frames/frame_05684.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_05713.jpg
# Extracted text:
# 다소 청결하지 못한 촛불 끄기
# Processing: /content/all_frames/frame_05742.jpg
# Extracted text:
# 다소 청결하지 못한 촛불끄기
# Processing: /content/all_frames/frame_05771.jpg
# Extracted text:
# 30
# 다소 청결하지 못한 촛불고기
# Processing: /content/all_frames/frame_05800.jpg
# Extracted text:
# 30
# 야 초록아 빨리 불어줘!!
# COM
# Processing: /content/all_frames/frame_05829.jpg
# Extracted text:
# 초록아 빨리 불어줘!
# Processing: /content/all_frames/frame_05858.jpg
# Extracted text:
# 30
# 질색하는 성아 ㅋㅋㅋ
# Processing: /content/all_frames/frame_05887.jpg
# Extracted text:
# 질색하는 성아 ㅋㅋㅋ
# Processing: /content/all_frames/frame_05916.jpg
# Extracted text:
# 질색하는 성아 ㅋㅋㅋ
# Processing: /content/all_frames/frame_05945.jpg
# Extracted text:
# 이게 뭐지..?
# 이모들이 가져온 풍선 사이에서 어리둥절.
# Processing: /content/all_frames/frame_05974.jpg
# Extracted text:
# "이게 뭐지..?
# 이모들이 가져온 풍선 사이에서 어리둥절.
# Processing: /content/all_frames/frame_06003.jpg
# Extracted text:
# 이게 뭐지..?
# 이모들이 가져온 풍선 사이에서 어리둥절.
# Processing: /content/all_frames/frame_06032.jpg
# Extracted text:
# 이게 뭐지..?
# 이모들이 가져온 풍선 사이에서 어리둥절
# Processing: /content/all_frames/frame_06061.jpg
# Extracted text:
# - 이게 뭐지..?
# 이모들이 가져온 풍선 사이에서 어리둥절.
# Processing: /content/all_frames/frame_06090.jpg
# Extracted text:
# 이게 뭐지..?
# 이모들이 가져온 풍선 사이에서 어리둥절.
# Processing: /content/all_frames/frame_06119.jpg
# Extracted text:
# "이게 뭐지..?
# 이모들이 가져온 풍선 사이에서 어리둥절.
# Processing: /content/all_frames/frame_06148.jpg
# Extracted text:
# 유준
# 둥절
# Processing: /content/all_frames/frame_06177.jpg
# Extracted text:
# 유준
# 둥절
# Processing: /content/all_frames/frame_06206.jpg
# Extracted text:
# 유준
# 둥절
# Processing: /content/all_frames/frame_06235.jpg
# Extracted text:
# 유준
# THE
# 둥절
# Processing: /content/all_frames/frame_06264.jpg
# Extracted text:
# 단비 더빙
# •(나는 즐겁지 않은데..)
# Processing: /content/all_frames/frame_06293.jpg
# Extracted text:
# 단비 더빙
# (나는 즐겁지 않은데)
# Processing: /content/all_frames/frame_06322.jpg
# Extracted text:
# 단비 더빙
# (나는 즐겁지 않은데)
# Processing: /content/all_frames/frame_06351.jpg
# Extracted text:
# 단비 더빙
# (왜 나를 귀찮게 하는 거야.
# Processing: /content/all_frames/frame_06380.jpg
# Extracted text:
# 담비 땡
# (왜 나를 귀찮게 하는거야)
# Processing: /content/all_frames/frame_06409.jpg
# Extracted text:
# 혹시 짱구야? ㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_06438.jpg
# Extracted text:
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_06467.jpg
# Extracted text:
# FFFFFFㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_06496.jpg
# Extracted text:
# 단비 더빙
# (왜 자기들만 좋으면 다냐고~)
# Processing: /content/all_frames/frame_06525.jpg
# Extracted text:
# 단비 더빙
# (왜 자기들만 좋으면 다냐고~)
# Processing: /content/all_frames/frame_06554.jpg
# Extracted text:
# 단비 더빙
# (왜 자기들만 좋으면 다냐고~)
# Processing: /content/all_frames/frame_06583.jpg
# Extracted text:
# 단비 더빙
# (왜 자기들만 좋으면 다냐고~)
# Processing: /content/all_frames/frame_06612.jpg
# Extracted text:
# 단비 더빙
# (퉤퉤칭이나 뱉어야제
# E
# Processing: /content/all_frames/frame_06641.jpg
# Extracted text:
# 단비 더빙
# (퉤퉤칭이나 뱉어야지
# E
# Processing: /content/all_frames/frame_06670.jpg
# Extracted text:
# 단비 더빙
# (퉤퉤침이나 뱉어야지!)
# Processing: /content/all_frames/frame_06699.jpg
# Extracted text:
# 갑자기
# Processing: /content/all_frames/frame_06728.jpg
# Extracted text:
# 갑자기 자덕소(?)
# Processing: /content/all_frames/frame_06757.jpg
# Extracted text:
# 비
# 이모들 풍선뺏더니 양손으로 잡고 있기 시작 ㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_06786.jpg
# Extracted text:
# 비
# 이모들 풍선뺏더니 양손으로 잡고 있기 시작 ㅋㅋㅋㅋㅋ.
# Processing: /content/all_frames/frame_06815.jpg
# Extracted text:
# -이모들풍선뺏더니 양손으로 잡고 있기 시작 ㅋㅋㅋㅋㅋ
# 비
# Processing: /content/all_frames/frame_06844.jpg
# Extracted text:
# 이모들 풍선뺏더니 양손으로 잡고 있기 시작 ㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_06873.jpg
# Extracted text:
# 이모들풍선뺏더니 양손으로 잡고 있기 시작ㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_06902.jpg
# Extracted text:
# 이 남자 앞으로 얼마나 더 강해질까?
# Processing: /content/all_frames/frame_06931.jpg
# Extracted text:
# 이 남자 앞으로 얼마나 더 강해질까?
# Processing: /content/all_frames/frame_06960.jpg
# Extracted text:
# '이 남자 앞으로 얼마나 더 강해질까..?
# Processing: /content/all_frames/frame_06989.jpg
# Extracted text:
# 이 남자 앞으로 얼마나 더 강해질까?
# Processing: /content/all_frames/frame_07018.jpg
# Extracted text:
# Apreny
# 이 남자 앞으로 얼마나 더 강해질까?
# Processing: /content/all_frames/frame_07047.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_07076.jpg
# Extracted text:
# 조유준?
# Processing: /content/all_frames/frame_07105.jpg
# Extracted text:
# ii
# Processing: /content/all_frames/frame_07134.jpg
# Extracted text:
# 어 정신차렸어? 이모가 불러서?
# Processing: /content/all_frames/frame_07163.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_07192.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_07221.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_07250.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_07279.jpg
# Extracted text:
# 유준이에게 사랑에 빠진 이모들 ㅋㅋㅋ
# Processing: /content/all_frames/frame_07308.jpg
# Extracted text:
# 유준이에게 사랑에 빠진 이모들 ㅋㅋㅋ
# Processing: /content/all_frames/frame_07337.jpg
# Extracted text:
# 어쩜 이렇게 예쁘고 귀엽냐고 난리 중ㅋㅋ
# Processing: /content/all_frames/frame_07366.jpg
# Extracted text:
# 어쩜 이렇게 예쁘고 귀엽냐고 난리 중 ㅋㅋ
# Processing: /content/all_frames/frame_07395.jpg
# Extracted text:
# 우와아아아!!!
# 우와아아아!!
# Processing: /content/all_frames/frame_07424.jpg
# Extracted text:
# 우와아아아!!
# 우와아아아!!
# Processing: /content/all_frames/frame_07453.jpg
# Extracted text:
# <반응이 너무 좋잖아~?)
# Processing: /content/all_frames/frame_07482.jpg
# Extracted text:
# <반응이 너무 좋잖아..?)
# Processing: /content/all_frames/frame_07511.jpg
# Extracted text:
# (반응이 너무 좋잖아..?)
# Processing: /content/all_frames/frame_07540.jpg
# Extracted text:
# (반응이 너무 좋잖아...?)
# Processing: /content/all_frames/frame_07569.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_07598.jpg
# Extracted text:
# (소리 질러!!!!!
# (소리질러!!
# Processing: /content/all_frames/frame_07627.jpg
# Extracted text:
# (소리 질러!!!!!!!!!
# Processing: /content/all_frames/frame_07656.jpg
# Extracted text:
# (소리 질러!!!!!!!!!!)
# Processing: /content/all_frames/frame_07685.jpg
# Extracted text:
# 용
# 유준이 한 번이라도 더 만지고 갈거라는 성아 ㅋㅋ
# Processing: /content/all_frames/frame_07714.jpg
# Extracted text:
# ΟΣΟ
# 용
# 유준이 한 번이라도 더 만지고 갈거라는 성아 ㅋㅋ
# Processing: /content/all_frames/frame_07743.jpg
# Extracted text:
# 유준이 한 번이라도 더 만지고 갈거라는 성아 ㅋㅋ
# Processing: /content/all_frames/frame_07772.jpg
# Extracted text:
# 유준이 한 번이라도 더 만지고 갈거라는 성의 ㅋㅋ
# Processing: /content/all_frames/frame_07801.jpg
# Extracted text:
# ΟΠΟ
# 용
# 유준이 한 번이라도 더 만지고 갈거라는 성아 쿠쿠
# Processing: /content/all_frames/frame_07830.jpg
# Extracted text:
# A
# 용
# 유준이 한 번이라도 더 만지고 갈거라는 성아 ㅋㅋ
# Processing: /content/all_frames/frame_07859.jpg
# Extracted text:
# CI
# 용
# 유준이 한 번이라도 더 만지고 갈거라는 성아 ㅋㅋ
# Processing: /content/all_frames/frame_07888.jpg
# Extracted text:
# 용
# 유준이 한 번이라도 더 만지고 갈거라는 성아 ㅋㅋ
# Processing: /content/all_frames/frame_07917.jpg
# Extracted text:
# 유준이 한 번이라도 더 만지고 갈거라는 성아 ㅋㅋ
# Processing: /content/all_frames/frame_07946.jpg
# Extracted text:
# 우와 오늘 구름 너무 이쁜디?
# Processing: /content/all_frames/frame_07975.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_08004.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_08033.jpg
# Extracted text:
# 세라젬 해보는 중인 성아 ㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_08062.jpg
# Extracted text:
# 세라젬 해보는 중인 성아 ㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_08091.jpg
# Extracted text:
# 다른 이모들은 유준이 홀릭
# Processing: /content/all_frames/frame_08120.jpg
# Extracted text:
# 다른 이모들은 유준이 홀릭
# Processing: /content/all_frames/frame_08149.jpg
# Extracted text:
# 유준이 낮잠자는 동안 이모들은 집갈 준비중
# Processing: /content/all_frames/frame_08178.jpg
# Extracted text:
# 유준이 낮잠자는동안 이모들은 집 갈 준비 중
# Processing: /content/all_frames/frame_08207.jpg
# Extracted text:
# 유준이 낮잠자는동안 이모들은 집 갈 준비 중
# 0
# Processing: /content/all_frames/frame_08236.jpg
# Extracted text:
# 조만간 또 놀러와 얘들아 ㅎㅎㅎㅎ
# Processing: /content/all_frames/frame_08265.jpg
# Extracted text:
# 조만간 또 놀러와얘들아 ㅎㅎ
# COM
# Processing: /content/all_frames/frame_08294.jpg
# Extracted text:
# 조만간 또 놀러와 얘들아 ㅎㅎ
# Processing: /content/all_frames/frame_08323.jpg
# Extracted text:
# 이모를 가고 금방 잠에서 깬 유주니
# IPC
# Processing: /content/all_frames/frame_08352.jpg
# Extracted text:
# 이모를 가고 금방 잠에서 깬 유주니
# IPC
# Processing: /content/all_frames/frame_08381.jpg
# Extracted text:
# 이모를 가고 금방 잠에서 깬 유주니
# IPC
# Processing: /content/all_frames/frame_08410.jpg
# Extracted text:
# ONEY
# 잠도 깼으니 엄마 아빠랑 침대에서 놀아보자고!
# IPC
# Processing: /content/all_frames/frame_08439.jpg
# Extracted text:
# ONEY
# 잠도 깼으니 엄마 아빠랑 침대에서 놀아보자고!
# IPC
# Processing: /content/all_frames/frame_08468.jpg
# Extracted text:
# amor
# 잠도 깼으니 엄마 아빠랑 침대에서 놀아보자고!
# IPC
# Processing: /content/all_frames/frame_08497.jpg
# Extracted text:
# 잠도 깼으니 엄마 아빠랑 침대에서 놀아보자고!
# IPC
# Processing: /content/all_frames/frame_08526.jpg
# Extracted text:
# 잠도 깼으니 엄마 아빠랑 침대에서 놀아보자고!
# IPC
# Processing: /content/all_frames/frame_08555.jpg
# Extracted text:
# 잠도 깼으니 엄마 아빠랑 침대에서 놀아보자고!
# IPC
# Processing: /content/all_frames/frame_08584.jpg
# Extracted text:
# 아빠 장난에 꺄르르 폭팔
# IPC
# Processing: /content/all_frames/frame_08613.jpg
# Extracted text:
# 아빠 장난에 꺄르르 폭팔
# IPC
# Processing: /content/all_frames/frame_08642.jpg
# Extracted text:
# 아빠 장난에꺄르르 폭팔
# IPC
# Processing: /content/all_frames/frame_08671.jpg
# Extracted text:
# 아빠 장난에 꺄르르 폭팔
# IPC
# Processing: /content/all_frames/frame_08700.jpg
# Extracted text:
# 아빠 장난에 꺄르르 폭팔
# IPC
# Processing: /content/all_frames/frame_08729.jpg
# Extracted text:
# S
# Processing: /content/all_frames/frame_08758.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_08787.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_08816.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_08845.jpg
# Extracted text:
# 이번엔 모자에 카메라 달고 몸으로 놀아주는중ㅋㅋ
# Processing: /content/all_frames/frame_08874.jpg
# Extracted text:
# 이번엔 모자에 카메라 달고 몸으로 놀아주는중 ㅋㅋ
# Processing: /content/all_frames/frame_08903.jpg
# Extracted text:
# 이번엔 모자에 카메라 달고 몸으로 놀아주는중ㅋㅋ
# Processing: /content/all_frames/frame_08932.jpg
# Extracted text:
# 이번엔 모자에 카메라 달고 몸으로 놀아주는 중 ㅋㅋ
# Processing: /content/all_frames/frame_08961.jpg
# Extracted text:
# 이번엔 모자에 카메라 달고 몸으로 놀아주는 중ㅋㅋ
# Processing: /content/all_frames/frame_08990.jpg
# Extracted text:
# 이것은 조땡 시점입니다. mov
# Processing: /content/all_frames/frame_09019.jpg
# Extracted text:
# 이것은 조땡 시점입니다. mov
# Processing: /content/all_frames/frame_09048.jpg
# Extracted text:
# 이것은 조땡 시점입니다. mov
# Processing: /content/all_frames/frame_09077.jpg
# Extracted text:
# 이것은 조땡 시점입니다. mov
# Processing: /content/all_frames/frame_09106.jpg
# Extracted text:
# 이것은 조팽 시점입니다. mov
# Processing: /content/all_frames/frame_09135.jpg
# Extracted text:
# 이것은 조팽 시점입니다. mov
# Processing: /content/all_frames/frame_09164.jpg
# Extracted text:
# 이것은 조땡 시점입니다. mov
# Processing: /content/all_frames/frame_09193.jpg
# Extracted text:
# 이것은 조땡 시점입니다. mov
# Processing: /content/all_frames/frame_09222.jpg
# Extracted text:
# 이것은 조땡 시점입니다. moys
# Processing: /content/all_frames/frame_09251.jpg
# Extracted text:
# 이것은 조땡 시점입니다.mov
# Processing: /content/all_frames/frame_09280.jpg
# Extracted text:
# 아이 재미있어!!
# Processing: /content/all_frames/frame_09309.jpg
# Extracted text:
# 일이 야속한
# 리
# Processing: /content/all_frames/frame_09338.jpg
# Extracted text:
# 세월이 야속한 그의 숨소리..
# Processing: /content/all_frames/frame_09367.jpg
# Extracted text:
# 세월이 야속한 그의 숨소리..
# Processing: /content/all_frames/frame_09396.jpg
# Extracted text:
# 세월이 야속한 그의 숨소리..
# Processing: /content/all_frames/frame_09425.jpg
# Extracted text:
# 힘들어..
# Processing: /content/all_frames/frame_09454.jpg
# Extracted text:
# 로봇청소기가 유준이를 끌 수 있을 거 같다는 조땡
# Processing: /content/all_frames/frame_09483.jpg
# Extracted text:
# 로봇청소기가 유준이를 끌 수 있을 거 같다는 조땡(?)
# Processing: /content/all_frames/frame_09512.jpg
# Extracted text:
# 로봇청소기가 유준이를 끌 수 있을 거 같다는 조땡(?)
# Processing: /content/all_frames/frame_09541.jpg
# Extracted text:
# 오빠 어차피 안 나갈 거 같은데
# Processing: /content/all_frames/frame_09570.jpg
# Extracted text:
# 오빠 어차피 안 나갈 거 같은데
# Processing: /content/all_frames/frame_09599.jpg
# Extracted text:
# 그거 왜 하고 있는 거야..?
# Processing: /content/all_frames/frame_09628.jpg
# Extracted text:
# (꼭해볼거야!)
# Processing: /content/all_frames/frame_09657.jpg
# Extracted text:
# (꼭해볼거야!)
# Processing: /content/all_frames/frame_09686.jpg
# Extracted text:
# 이상한거 시켜서 많이 화난 청소기 ㅋㅋ
# Processing: /content/all_frames/frame_09715.jpg
# Extracted text:
# 이상한거 시켜서 많이 화난 청소기 ㅋㅋ
# Processing: /content/all_frames/frame_09744.jpg
# Extracted text:
# 이상한거 시켜서 많이 화난 청소기 ㅋㅋ
# Processing: /content/all_frames/frame_09773.jpg
# Extracted text:
# 방금 로봇청소기 묶었다가
# Processing: /content/all_frames/frame_09802.jpg
# Extracted text:
# 방금 로봇청소기 묶었다가
# Processing: /content/all_frames/frame_09831.jpg
# Extracted text:
# 로봇청소기가 (당연히) 안 나가니까....
# Processing: /content/all_frames/frame_09860.jpg
# Extracted text:
# (질질)
# 로봇청소기가 (당연히) 안 나가니까..
# Processing: /content/all_frames/frame_09889.jpg
# Extracted text:
# Dr
# (질질)
# Processing: /content/all_frames/frame_09918.jpg
# Extracted text:
# Dr
# SOURNEY
# (질질)
# 지금 저렇게 하고 있어요
# Processing: /content/all_frames/frame_09947.jpg
# Extracted text:
# Dr
# OURNEY
# (질질)
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_09976.jpg
# Extracted text:
# Dr
# UKET
# (질질)
# FFFFㅋㅋㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_10005.jpg
# Extracted text:
# (질질)
# 유준아 재미있지!?
# Processing: /content/all_frames/frame_10034.jpg
# Extracted text:
# (질질)
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋE
# Processing: /content/all_frames/frame_10063.jpg
# Extracted text:
# (질질)
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_10092.jpg
# Extracted text:
# JOURNE
# (질질)
# 너무 귀여워♥
# Processing: /content/all_frames/frame_10121.jpg
# Extracted text:
# JOURNEY
# 아 너무 쪼그맣다 쟤♥
# Processing: /content/all_frames/frame_10150.jpg
# Extracted text:
# JOURNEY
# 아 너무 쪼그맣다 쟤♥
# Processing: /content/all_frames/frame_10179.jpg
# Extracted text:
# 아빠랑 같이 산책가자~!
# Processing: /content/all_frames/frame_10208.jpg
# Extracted text:
# 아빠랑 같이 산책 가자~!
# Processing: /content/all_frames/frame_10237.jpg
# Extracted text:
# 아빠랑 같이 산책 가자~!
# Processing: /content/all_frames/frame_10266.jpg
# Extracted text:
# 너의 표정은 엄마가 보고 있다!
# Processing: /content/all_frames/frame_10295.jpg
# Extracted text:
# 너의 표정은 엄마가 보고 있다!
# JOUANE
# Processing: /content/all_frames/frame_10324.jpg
# Extracted text:
# JOURNEY
# 범보의자 앞에 세워둔 카메라 ㅋㅋ
# Processing: /content/all_frames/frame_10353.jpg
# Extracted text:
# 범보의자 앞에 세워둔 카메라 ㅋㅋ
# Processing: /content/all_frames/frame_10382.jpg
# Extracted text:
# Insta360
# 범보의자 앞에 세워둔 카메라 ㅋㅋ
# Processing: /content/all_frames/frame_10411.jpg
# Extracted text:
# Insta360
# 범보의자 앞에 세워둔 카메라 ㅋㅋ
# Processing: /content/all_frames/frame_10440.jpg
# Extracted text:
# 범보의자 앞에 세워둔 카메라 ㅋㅋ
# Processing: /content/all_frames/frame_10469.jpg
# Extracted text:
# 영문도 모른 채 끌려가는 조유준 ㅋㅋ
# Processing: /content/all_frames/frame_10498.jpg
# Extracted text:
# JOURN
# •영문도 모른 채 끌려가는 조유준 ㅋㅋ
# Processing: /content/all_frames/frame_10527.jpg
# Extracted text:
# JOURN
# 영문도 모른 채 끌려가는 조유준 ㅋㅋ
# Processing: /content/all_frames/frame_10556.jpg
# Extracted text:
# 영문도 모른 채 끌려가는 조유준 ㅋㅋ
# Processing: /content/all_frames/frame_10585.jpg
# Extracted text:
# 영문도 모른 채 끌려가는 조유준 ㅋ3
# Processing: /content/all_frames/frame_10614.jpg
# Extracted text:
# 영문도 모른 채 끌려가는 조유준 ㅋㅋ
# Processing: /content/all_frames/frame_10643.jpg
# Extracted text:
# JOURNEY
# 영문도 모른 채 끌려가는 조유준 ㅋㅋ
# Processing: /content/all_frames/frame_10672.jpg
# Extracted text:
# JO
# (나 어디로 가는 건가요..?)
# Processing: /content/all_frames/frame_10701.jpg
# Extracted text:
# (나 어디로 가는 건가요..?)
# Processing: /content/all_frames/frame_10730.jpg
# Extracted text:
# JOURNEY
# (나 어디로 가는 건가요..?)
# Processing: /content/all_frames/frame_10759.jpg
# Extracted text:
# JOURNEY
# (나 어디로 가는 건가요..?)
# Processing: /content/all_frames/frame_10788.jpg
# Extracted text:
# JOURNEY
# 아 조유준 왜 이렇게 귀여워!!
# Processing: /content/all_frames/frame_10817.jpg
# Extracted text:
# Dr
# 아 조유준 왜 이렇게 귀여워!!
# Processing: /content/all_frames/frame_10846.jpg
# Extracted text:
# ?????
# Processing: /content/all_frames/frame_10875.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_10904.jpg
# Extracted text:
# 77777
# JOURNEY
# 빙글빙글 돌아가요오~♬
# Processing: /content/all_frames/frame_10933.jpg
# Extracted text:
# ?????
# 빙글빙글 돌아가요오~.
# Processing: /content/all_frames/frame_10962.jpg
# Extracted text:
# 빙글빙글 돌아가요오오~!
# Processing: /content/all_frames/frame_10991.jpg
# Extracted text:
# 빙글빙글 돌아가요오오~♬
# Processing: /content/all_frames/frame_11020.jpg
# Extracted text:
# 빙글빙글 돌아가요오오~♬
# Processing: /content/all_frames/frame_11049.jpg
# Extracted text:
# (아부지, 나 멀미 날라해..)
# Processing: /content/all_frames/frame_11078.jpg
# Extracted text:
# (아부지 나 멀미 날라해)
# Processing: /content/all_frames/frame_11107.jpg
# Extracted text:
# "(아부지 나 멀미 날라해..)
# Processing: /content/all_frames/frame_11136.jpg
# Extracted text:
# (아부지 나 멀미 날라해
# Processing: /content/all_frames/frame_11165.jpg
# Extracted text:
# 유치원에서 돌아온 먹태 픽업 완료!
# Processing: /content/all_frames/frame_11194.jpg
# Extracted text:
# 유치원에서 돌아온 먹태 픽업 완료!!
# Processing: /content/all_frames/frame_11223.jpg
# Extracted text:
# 유치원에서 돌아온 먹태 픽업 완료!
# Processing: /content/all_frames/frame_11252.jpg
# Extracted text:
# 오늘도 친구들이랑 아주 즐겁게 논 모양 ㅋㅋ
# Processing: /content/all_frames/frame_11281.jpg
# Extracted text:
# 오늘도 친구들이랑 아주 즐겁게 논 모양 ㅋㅋ
# Processing: /content/all_frames/frame_11310.jpg
# Extracted text:
# 아주 그냥 재미있었어 친구들이랑?
# Processing: /content/all_frames/frame_11339.jpg
# Extracted text:
# 아주 그냥 재미있었어 친구들이랑?
# Processing: /content/all_frames/frame_11368.jpg
# Extracted text:
# 아주 그냥 재미있었어 친구들이랑?
# Processing: /content/all_frames/frame_11397.jpg
# Extracted text:
# 재미있게 놀았어?
# Processing: /content/all_frames/frame_11426.jpg
# Extracted text:
# 집 와서 장난감 갖고 노는 꼬질이
# Processing: /content/all_frames/frame_11455.jpg
# Extracted text:
# 집와서 장난감 갖고 노는 꼬질이
# Processing: /content/all_frames/frame_11484.jpg
# Extracted text:
# 조만간 미용하러 갑시다 유먹태씨
# Processing: /content/all_frames/frame_11513.jpg
# Extracted text:
# 조만간 미용하러 갑시다 유먹태쎄
# Processing: /content/all_frames/frame_11542.jpg
# Extracted text:
# 조만간 미용하러 갑시다 유먹태씨
# Processing: /content/all_frames/frame_11571.jpg
# Extracted text:
# 부산 다녀온 후 얼굴에 태열이랑 침독이 올라와서
# IPC
# Processing: /content/all_frames/frame_11600.jpg
# Extracted text:
# 부산 다녀온 후 얼굴에 태열이랑 침독이 올라와서
# IPC
# Processing: /content/all_frames/frame_11629.jpg
# Extracted text:
# 잘 때 얼굴에 수딩크림 발라주고 있어요
# IPC
# Processing: /content/all_frames/frame_11658.jpg
# Extracted text:
# 잘 때 얼굴에 수딩크림 발라주고 있어요
# IPC
# Processing: /content/all_frames/frame_11687.jpg
# Extracted text:
# 잘 때 얼굴에 수딩크림 발라주고 있어요
# IPC
# Processing: /content/all_frames/frame_11716.jpg
# Extracted text:
# 3시간 뒤, 새벽 수유하러 재등장
# IPC
# Processing: /content/all_frames/frame_11745.jpg
# Extracted text:
# 3시간 뒤, 새벽 수유하려 재등장
# IPC
# Processing: /content/all_frames/frame_11774.jpg
# Extracted text:
# 01
# 3시간 뒤, 새벽 수유하러 재등장
# IPC
# Processing: /content/all_frames/frame_11803.jpg
# Extracted text:
# 혜주가 밥 먹이는 동안 조땡은 기저귀 갈기
# IPC
# Processing: /content/all_frames/frame_11832.jpg
# Extracted text:
# 혜주가 밥 먹이는 동안 조땡은 기저귀 갈기
# IPC
# Processing: /content/all_frames/frame_11861.jpg
# Extracted text:
# 혜주가 밥 먹이는 동안 조땡은 기저귀 갈기
# IPC
# Processing: /content/all_frames/frame_11890.jpg
# Extracted text:
# 혜주가 밥 먹이는 동안 조땡은 기저귀 갈기
# IPC
# Processing: /content/all_frames/frame_11919.jpg
# Extracted text:
# ก
# C
# 트림 시키다가 의문의 1방
# Processing: /content/all_frames/frame_11948.jpg
# Extracted text:
# C
# 트림 시키다가 의문의 1방
# Processing: /content/all_frames/frame_11977.jpg
# Extracted text:
# C
# Processing: /content/all_frames/frame_12006.jpg
# Extracted text:
# C
# 참아야하느니라.. 참아야..
# Processing: /content/all_frames/frame_12035.jpg
# Extracted text:
# C
# 참아야하느니라 잡아야
# Processing: /content/all_frames/frame_12064.jpg
# Extracted text:
# 배도 부르니 다시 잠에 빠져듭니ㄷ..
# IPC
# Processing: /content/all_frames/frame_12093.jpg
# Extracted text:
# 배도 부르니 다시 잠에 빠져듭니ㄷ..
# IPC
# Processing: /content/all_frames/frame_12122.jpg
# Extracted text:
# 배도 부르니 다시 잠에 빠져듭니ㄷ..
# IPC
# Processing: /content/all_frames/frame_12151.jpg
# Extracted text:
# 배도 부르니 다시 잠에 빠져듭니ㄷ..
# IPO
# Processing: /content/all_frames/frame_12180.jpg
# Extracted text:
# 배도 부르니 다시 잠에 빠져듭니ㄷ..
# IP
# Processing: /content/all_frames/frame_12209.jpg
# Extracted text:
# 7월 27일
# 아침에 슬쩍 유준이 옆에 누워서 같이 자고 있는 조땡
# IPC
# Processing: /content/all_frames/frame_12238.jpg
# Extracted text:
# 7월 27일
# 아침에 슬쩍 유준이 옆에 누워서 같이 자고 있는 조땡
# IPC
# Processing: /content/all_frames/frame_12267.jpg
# Extracted text:
# 7월 27일
# 아침에 슬쩍 유준이 옆에 누워서 같이 자고 있는 조땡
# IPC
# Processing: /content/all_frames/frame_12296.jpg
# Extracted text:
# 유준아 혹시 꿈에서 벌 받고 있니..?
# Processing: /content/all_frames/frame_12325.jpg
# Extracted text:
# 유준아 혹시 꿈에서 벌 받고 있니..?
# Processing: /content/all_frames/frame_12354.jpg
# Extracted text:
# 유준아 혹시 꿈에서 벌 받고 있니..?
# Processing: /content/all_frames/frame_12383.jpg
# Extracted text:
# 이 상태로 3시간 더 잤음 ㅋㅋㅋ
# Processing: /content/all_frames/frame_12412.jpg
# Extracted text:
# 이 상태로 3시간 더 잤음 ㅋㅋㅋ
# Processing: /content/all_frames/frame_12441.jpg
# Extracted text:
# 이 상태로 3시간 더 잤음 ㅋㅋㅋ
# Processing: /content/all_frames/frame_12470.jpg
# Extracted text:
# 지금 너무너무 정신이 없는데요..
# Processing: /content/all_frames/frame_12499.jpg
# Extracted text:
# 지금 너무너무 정신이 없는데요..
# Processing: /content/all_frames/frame_12528.jpg
# Extracted text:
# 오늘은 저희 PD님이
# Processing: /content/all_frames/frame_12557.jpg
# Extracted text:
# 오늘은 저희 PD님이
# Processing: /content/all_frames/frame_12586.jpg
# Extracted text:
# 집에 오시거든요?
# Processing: /content/all_frames/frame_12615.jpg
# Extracted text:
# 근데 보통 집에 손님 오면 배달 음식을 많이 먹는데
# Processing: /content/all_frames/frame_12644.jpg
# Extracted text:
# 근데 보통 집에 손님 오면 배달 음식을 많이 먹는데
# Processing: /content/all_frames/frame_12673.jpg
# Extracted text:
# 근데 보통 집에 손님 오면 배달 음식을 많이 먹는데
# Processing: /content/all_frames/frame_12702.jpg
# Extracted text:
# PD님은 제가 요리하는 모습을 많이 봤잖아요?
# Processing: /content/all_frames/frame_12731.jpg
# Extracted text:
# PD님은 제가 요리하는 모습을 많이 봤잖아요?
# Processing: /content/all_frames/frame_12760.jpg
# Extracted text:
# PD님은 제가 요리하는 모습을 많이 봤잖아요?
# Processing: /content/all_frames/frame_12789.jpg
# Extracted text:
# 초땡표밥상 맛 좀 보여드리기!
# Processing: /content/all_frames/frame_12818.jpg
# Extracted text:
# 조땡표 밥상 맛 좀 보여드리기!
# Processing: /content/all_frames/frame_12847.jpg
# Extracted text:
# 조땡표 밥상 맛 좀 보여드리기!
# Processing: /content/all_frames/frame_12876.jpg
# Extracted text:
# 가족 이외 사람에게 차려주는 건 오랜만이라 급 긴장 ㅋㅋ
# Processing: /content/all_frames/frame_12905.jpg
# Extracted text:
# 가족 이외 사람에게 차려주는 건 오랜만이라 급 긴장 ㅋㅋ
# Processing: /content/all_frames/frame_12934.jpg
# Extracted text:
# 가족 이외 사람에게 차려주는 건 오랜만이라 긴장 ㅋㅋ
# Ol
# Oi
# Processing: /content/all_frames/frame_12963.jpg
# Extracted text:
# 가족 이외 사람에게 차려주는 건 오랜만이라급 긴장 ㅋㅋ
# Processing: /content/all_frames/frame_12992.jpg
# Extracted text:
# 가족 이외 사람에게 차려주는 건 오랜만이라 급 긴장 ㅋㅋ
# Processing: /content/all_frames/frame_13021.jpg
# Extracted text:
# 정신없지만 열심히 완성돼가는 닭갈비랑 된장찌개
# Processing: /content/all_frames/frame_13050.jpg
# Extracted text:
# 정신없지만 열심히 완성돼가는 닭갈비랑 된장찌개
# Processing: /content/all_frames/frame_13079.jpg
# Extracted text:
# 정신없지만 열심히 완성돼가는 닭갈비랑 된장찌개
# Magic
# Processing: /content/all_frames/frame_13108.jpg
# Extracted text:
# 드디어 영상에서만 보던 조땡표 음식
# Processing: /content/all_frames/frame_13137.jpg
# Extracted text:
# 드디어 영상에서만 보던 조땡표 음식
# Gray
# Processing: /content/all_frames/frame_13166.jpg
# Extracted text:
# 드디어 영상에서만 보던 조땡표 음식
# Grayp
# Processing: /content/all_frames/frame_13195.jpg
# Extracted text:
# 제가 대표로 한 번 먹어보겠습니다
# Gray
# Processing: /content/all_frames/frame_13224.jpg
# Extracted text:
# 제가 대표로 한 번 먹어보겠습니다
# Gray Pa
# Processing: /content/all_frames/frame_13253.jpg
# Extracted text:
# 제가 대표로 한 번 먹어보겠습니다!
# Processing: /content/all_frames/frame_13282.jpg
# Extracted text:
# 음식 잘하네
# Processing: /content/all_frames/frame_13311.jpg
# Extracted text:
# 5.0
# 이 집 음식 잘하네
# Processing: /content/all_frames/frame_13340.jpg
# Extracted text:
# 5.0
# 이 집 음식 잘하네
# Processing: /content/all_frames/frame_13369.jpg
# Extracted text:
# 피디님이 사오신 선물 언박싱
# Processing: /content/all_frames/frame_13398.jpg
# Extracted text:
# 피디님이 사오신 선물 언박싱
# Processing: /content/all_frames/frame_13427.jpg
# Extracted text:
# 피디님이 사오신 선물 언박싱
# Processing: /content/all_frames/frame_13456.jpg
# Extracted text:
# 유준이 사진 (핸드폰으로) 키고
# Processing: /content/all_frames/frame_13485.jpg
# Extracted text:
# Dr.
# 보면서 어울리는 걸로 고르셨대ㅋㅋ
# Processing: /content/all_frames/frame_13514.jpg
# Extracted text:
# agabang
# 보면서 어울리는 걸로 고르셨대ㅋㅋ
# Processing: /content/all_frames/frame_13543.jpg
# Extracted text:
# agabang
# 심각..
# (최고의 선물을 찾기 위한 노력),
# 1:
# Processing: /content/all_frames/frame_13572.jpg
# Extracted text:
# (최고의 선물을 찾기 위한 노력),
# 심각..
# 1:
# Processing: /content/all_frames/frame_13601.jpg
# Extracted text:
# EEE
# Processing: /content/all_frames/frame_13630.jpg
# Extracted text:
# EEEEEEEEEE
# Processing: /content/all_frames/frame_13659.jpg
# Extracted text:
# EEEEEEE
# Sup
# Processing: /content/all_frames/frame_13688.jpg
# Extracted text:
# 아직 입혀보진 않았지만 벌써 귀엽다;; ~
# Processing: /content/all_frames/frame_13717.jpg
# Extracted text:
# 아직 입혀보진 않았지만 벌써 귀엽다"
# Processing: /content/all_frames/frame_13746.jpg
# Extracted text:
# 아직 입혀보진 않았지만 벌써 귀엽다;;"
# Processing: /content/all_frames/frame_13775.jpg
# Extracted text:
# 아직 입혀보진 않았지만 벌써 귀엽다"
# Processing: /content/all_frames/frame_13804.jpg
# Extracted text:
# Dr
# 아직 입혀보진 않았지만 벌써 귀엽다"
# Processing: /content/all_frames/frame_13833.jpg
# Extracted text:
# 아직 입혀보진 않았지만 벌써 귀엽다;;
# Processing: /content/all_frames/frame_13862.jpg
# Extracted text:
# 디즈니는 당장 도널드덕 실사화를 해라!
# Processing: /content/all_frames/frame_13891.jpg
# Extracted text:
# 디즈니는 당장 도널드덕 실사화를 해라!
# Processing: /content/all_frames/frame_13920.jpg
# Extracted text:
# 디즈니는 당장 도널드덕 실사화를 해라!
# Processing: /content/all_frames/frame_13949.jpg
# Extracted text:
# 95757
# 조널드덕을 국회로!
# Processing: /content/all_frames/frame_13978.jpg
# Extracted text:
# 조널드덕을 국회로!
# Processing: /content/all_frames/frame_14007.jpg
# Extracted text:
# 조널드덕을 국회로!
# Processing: /content/all_frames/frame_14036.jpg
# Extracted text:
# 분명 1살까지 입을 수 있다고 하셨는데.. (머쓱)
# Processing: /content/all_frames/frame_14065.jpg
# Extracted text:
# 분명 1살까지 입을 수 있다고 하셨는데.. (머쓱)
# Processing: /content/all_frames/frame_14094.jpg
# Extracted text:
# 분명 1살까지 입을 수 있다고 하셨는데.. (머쓱)
# Processing: /content/all_frames/frame_14123.jpg
# Extracted text:
# 분명 1살까지 입을 수 있다고 하셨는데..(머쓱)
# Processing: /content/all_frames/frame_14152.jpg
# Extracted text:
# 여기 앞에를 조금 못 내려 이거?
# Processing: /content/all_frames/frame_14181.jpg
# Extracted text:
# 여기 앞에를 조금 못 내려 이거?
# Processing: /content/all_frames/frame_14210.jpg
# Extracted text:
# 죄송한데 지금도 꽉끼세요 ㅅ
# Processing: /content/all_frames/frame_14239.jpg
# Extracted text:
# 죄송한데 지금도 꽉끼세요
# Processing: /content/all_frames/frame_14268.jpg
# Extracted text:
# 죄송한데 지금도 꽉끼세요!
# Processing: /content/all_frames/frame_14297.jpg
# Extracted text:
# 죄송한데 지금도 꽉끼세요!
# Processing: /content/all_frames/frame_14326.jpg
# Extracted text:
# THE BEST DOG
# 이건 피디님이 만들어주신 먹태 티셔츠 ㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_14355.jpg
# Extracted text:
# THE BEST DOG
# FRAKTAR
# 이건 피디님이 만들어주신 먹태 티셔츠 ㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_14384.jpg
# Extracted text:
# THE BEST DOG
# MUKTAB
# 이건 피디님이 만들어주신 먹태 티셔츠 ㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_14413.jpg
# Extracted text:
# THE BEST DOG
# PRACT
# 이건 피디님이 만들어주신 먹태 티셔츠 ㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_14442.jpg
# Extracted text:
# 아 먹태 니 거야(?)
# Processing: /content/all_frames/frame_14471.jpg
# Extracted text:
# 아 먹태니 거야(?)
# Processing: /content/all_frames/frame_14500.jpg
# Extracted text:
# 너야 ㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_14529.jpg
# Extracted text:
# THE BEST DOG
# MUKTAL
# 하나도 귀여운데, 귀여운 애가 7이나!
# Processing: /content/all_frames/frame_14558.jpg
# Extracted text:
# THE BEST DOG
# PURTA
# 하나도 귀여운데, 귀여운 애가 7이나!
# Processing: /content/all_frames/frame_14587.jpg
# Extracted text:
# THE BLU.
# 하나도 귀여운데, 귀여운 애가 이나!
# Processing: /content/all_frames/frame_14616.jpg
# Extracted text:
# THE BOO
# 하나도 귀여운데, 귀여운 애가 7이나!
# Processing: /content/all_frames/frame_14645.jpg
# Extracted text:
# 1
# 야 이거 BTS 아닙니까 이거???
# Dr
# Processing: /content/all_frames/frame_14674.jpg
# Extracted text:
# 야 이거 BTS 아닙니까 이거???
# Processing: /content/all_frames/frame_14703.jpg
# Extracted text:
# 요런 느낌 생각하면서 구매하셨다는 ㅋㅋㅋ
# Processing: /content/all_frames/frame_14732.jpg
# Extracted text:
# 요런 느낌 생각하면서 구매하셨다는 ㅋㅋㅋ
# Processing: /content/all_frames/frame_14761.jpg
# Extracted text:
# 요런 느낌 생각하면서 구매하셨다는 ㅋㅋㅋ
# Processing: /content/all_frames/frame_14790.jpg
# Extracted text:
# 요런 느낌 생각하면서 구매하셨다는 ㅋㅋㅋ
# Processing: /content/all_frames/frame_14819.jpg
# Extracted text:
# 요런 느낌 생각하면서 구매하셨다는 ㅋㅋㅋ
# Processing: /content/all_frames/frame_14848.jpg
# Extracted text:
# 역시 청이 찰떡이세요♡
# Processing: /content/all_frames/frame_14877.jpg
# Extracted text:
# 역시 청이 찰떡이세요♡
# Processing: /content/all_frames/frame_14906.jpg
# Extracted text:
# 역시 청이 찰떡이세요♡
# Processing: /content/all_frames/frame_14935.jpg
# Extracted text:
# 아니 근데 그 청모자 쓴 거 봤죠!?
# Processing: /content/all_frames/frame_14964.jpg
# Extracted text:
# 아니 근데 그 청모자 쓴 거 봤죠!?
# Processing: /content/all_frames/frame_14993.jpg
# Extracted text:
# 그니까 청이 잘 어울려 유준이가 그치?
# Processing: /content/all_frames/frame_15022.jpg
# Extracted text:
# 그니까 청이 잘 어울려 유준이가 그치?
# Processing: /content/all_frames/frame_15051.jpg
# Extracted text:
# 하얘서 그런가?
# Processing: /content/all_frames/frame_15080.jpg
# Extracted text:
# 아 귀여워~
# Processing: /content/all_frames/frame_15109.jpg
# Extracted text:
# ㅣ좋겠다(?)
# Processing: /content/all_frames/frame_15138.jpg
# Extracted text:
# 좋겠다 유준아(?)
# Processing: /content/all_frames/frame_15167.jpg
# Extracted text:
# PD님한테 손톱 깎는 거 보여드리는 중
# Processing: /content/all_frames/frame_15196.jpg
# Extracted text:
# PD님한테 손톱 깎는 거 보여드리는 중
# Processing: /content/all_frames/frame_15225.jpg
# Extracted text:
# PD님한테 손톱깎는거 보여드리는중
# Processing: /content/all_frames/frame_15254.jpg
# Extracted text:
# PD님한테 손톱깎는거 보여드리는 중
# Processing: /content/all_frames/frame_15283.jpg
# Extracted text:
# PD님한테 손톱깎는거 보여드리는 중
# Processing: /content/all_frames/frame_15312.jpg
# Extracted text:
# PD님한테 손톱깎는거 보여드리는중
# Processing: /content/all_frames/frame_15341.jpg
# Extracted text:
# (PD : 손톱이 개미똥구멍만해서 진짜 말도 안됨)
# Processing: /content/all_frames/frame_15370.jpg
# Extracted text:
# (PD : 손톱이 개미똥구멍만해서 진짜 말도 안됨)
# Processing: /content/all_frames/frame_15399.jpg
# Extracted text:
# (PD: 손톱이 개미똥구멍만해서 진짜 말도 안됨)
# Processing: /content/all_frames/frame_15428.jpg
# Extracted text:
# (PD: 손톱이 개미똥구멍만해서 진짜 말도 안 됨)
# Processing: /content/all_frames/frame_15457.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_15486.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_15515.jpg
# Extracted text:
# (Kijul...)
# Processing: /content/all_frames/frame_15544.jpg
# Extracted text:
# 00
# 이대로 시간이 멈추길..
# Processing: /content/all_frames/frame_15573.jpg
# Extracted text:
# 이대로 시간이 멈추길..
# 18
# Processing: /content/all_frames/frame_15602.jpg
# Extracted text:
# 이대로 시간이 멈추길..
# 8
# Processing: /content/all_frames/frame_15631.jpg
# Extracted text:
# 이대로 시간이 멈추길..
# Processing: /content/all_frames/frame_15660.jpg
# Extracted text:
# (먹태 선물로 사오신 강아지 인형)
# Processing: /content/all_frames/frame_15689.jpg
# Extracted text:
# (먹태 선물로 사오신 강아지 인형)
# Processing: /content/all_frames/frame_15718.jpg
# Extracted text:
# (먹태 선물로 사오신 강아지 인형)
# Processing: /content/all_frames/frame_15747.jpg
# Extracted text:
# (먹태 선물로 사오신 강아지 인형)
# Processing: /content/all_frames/frame_15776.jpg
# Extracted text:
# 바로 가지고 놀다가 뜯어진 모가지..
# Processing: /content/all_frames/frame_15805.jpg
# Extracted text:
# 바로 가지고 놀다가 뜯어진 모가지..
# Processing: /content/all_frames/frame_15834.jpg
# Extracted text:
# 바로 가지고 놀다가 뜯어진 모가지.
# Processing: /content/all_frames/frame_15863.jpg
# Extracted text:
# 두 시간 만에 그렇게...
# Processing: /content/all_frames/frame_15892.jpg
# Extracted text:
# 아니야 두 시간이 아니고
# Processing: /content/all_frames/frame_15921.jpg
# Extracted text:
# 15분 그쵸?
# FACC
# Processing: /content/all_frames/frame_15950.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_15979.jpg
# Extracted text:
# 아 님은 15분만에 가셨습니다..
# Processing: /content/all_frames/frame_16008.jpg
# Extracted text:
# 아 님은 15분만에 가셨습니다..
# Processing: /content/all_frames/frame_16037.jpg
# Extracted text:
# 아 님은 15분만에 가셨습니다..
# Processing: /content/all_frames/frame_16066.jpg
# Extracted text:
# 원래 여기 밧줄이 있었어(?)
# Processing: /content/all_frames/frame_16095.jpg
# Extracted text:
# ...
# Extracted text:
# FO
# Ohu
# FO
# yo
# Processing: /content/all_frames/frame_19459.jpg
# Extracted text:
# HO
# 롬
# 어
# Processing: /content/all_frames/frame_19488.jpg
# Extracted text:
# oku
# 어
# oku
# Processing: /content/all_frames/frame_19517.jpg
# Extracted text:
# FO
# aku
# Processing: /content/all_frames/frame_19546.jpg
# Extracted text:
# 엄마 빨래 접는 거 볼래??
# Processing: /content/all_frames/frame_19575.jpg
# Extracted text:
# 봐봐 이거 봐봐? 유준이 바지?
# Processing: /content/all_frames/frame_19604.jpg
# Extracted text:
# 봐봐 이거 봐봐? 유준이 바지?
# Processing: /content/all_frames/frame_19633.jpg
# Extracted text:
# (내 바지!
# Processing: /content/all_frames/frame_19662.jpg
# Extracted text:
# (내 바지)
# Processing: /content/all_frames/frame_19691.jpg
# Extracted text:
# (내 바지)
# (별 관심 없는 듯..)
# Processing: /content/all_frames/frame_19720.jpg
# Extracted text:
# 와 이제 유준이를 옆에다 두고
# Processing: /content/all_frames/frame_19749.jpg
# Extracted text:
# 와 이제 유준이를 옆에다 두고
# Processing: /content/all_frames/frame_19778.jpg
# Extracted text:
# 이런 빨래도 접을 수 있다니!
# Processing: /content/all_frames/frame_19807.jpg
# Extracted text:
# 이런 빨래도 접을 수 있다니!
# Processing: /content/all_frames/frame_19836.jpg
# Extracted text:
# No text detected.
# Processing: /content/all_frames/frame_19865.jpg
# Extracted text:
# 감동 그 잡채의 순간..
# Processing: /content/all_frames/frame_19894.jpg
# Extracted text:
# 감동 그 잡채의 순간..
# Processing: /content/all_frames/frame_19923.jpg
# Extracted text:
# 혹시 치발기 하실
# Processing: /content/all_frames/frame_19952.jpg
# Extracted text:
# 혹시 치발기 하실
# Processing: /content/all_frames/frame_19981.jpg
# Extracted text:
# 혹시 치발기 하실 유준 선생님?
# Processing: /content/all_frames/frame_20010.jpg
# Extracted text:
# (빨리 주세요!)
# 기다렸다는 듯이 바로 입으로 직행 ㅋㅋ
# Processing: /content/all_frames/frame_20039.jpg
# Extracted text:
# (빨리 주세요!)
# 기다렸다는 듯이 바로 입으로 직행 ㅋㅋ
# Processing: /content/all_frames/frame_20068.jpg
# Extracted text:
# (빨리 주세요!)
# 기다렸다는 듯이 바로 입으로 직행 ㅋㅋ
# Processing: /content/all_frames/frame_20097.jpg
# Extracted text:
# (빨리 주세요!)
# 기다렸다는 듯이 바로 입으로 직행 ㅋㅋ
# Processing: /content/all_frames/frame_20126.jpg
# Extracted text:
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# Processing: /content/all_frames/frame_20155.jpg
# Extracted text:
# "기다렸어 조유준~?
# Processing: /content/all_frames/frame_20184.jpg
# Extracted text:
# 기다렸어 조유준~?
# Processing: /content/all_frames/frame_20213.jpg
# Extracted text:
# 야 너 기다렸어~? (웃겨 정말)
# Processing: /content/all_frames/frame_20242.jpg
# Extracted text:
# (혼자 있으니 급 차분)
# 지금 저녁인데요
# Processing: /content/all_frames/frame_20271.jpg
# Extracted text:
# (혼자 있으니 급 차분)
# 지금 저녁인데요
# Processing: /content/all_frames/frame_20300.jpg
# Extracted text:
# 저는 먹태 빗질한다고
# Processing: /content/all_frames/frame_20329.jpg
# Extracted text:
# 저는 먹태 빗질한다고
# Processing: /content/all_frames/frame_20358.jpg
# Extracted text:
# 아무 것도 못하고 빗질만 하다가
# Processing: /content/all_frames/frame_20387.jpg
# Extracted text:
# 아무 것도 못하고 빗질만 하다가
# Processing: /content/all_frames/frame_20416.jpg
# Extracted text:
# 안마의자 한 번 했다가
# Processing: /content/all_frames/frame_20445.jpg
# Extracted text:
# 이제 유준이 꿈수하려고요
# Processing: /content/all_frames/frame_20474.jpg
# Extracted text:
# 이제 유준이 꿈수하려고요
# Processing: /content/all_frames/frame_20503.jpg
# Extracted text:
# 근데 저 오늘은!
# Processing: /content/all_frames/frame_20532.jpg
# Extracted text:
# 우리 아들이랑 자야지♡
# Processing: /content/all_frames/frame_20561.jpg
# Extracted text:
# 우리 아들이랑 자야지♡
# Processing: /content/all_frames/frame_20590.jpg
# Extracted text:
# 오잉?
# Processing: /content/all_frames/frame_20619.jpg
# Extracted text:
# 어디로 갔지? 먹태가?
# Processing: /content/all_frames/frame_20648.jpg
# Extracted text:
# (쓰윽)
# Processing: /content/all_frames/frame_20677.jpg
# Extracted text:
# 여기 있다 ㅋㅋㅋ
# Processing: /content/all_frames/frame_20706.jpg
# Extracted text:
# 세라젬 뒤에 뻗은 먹탱이 ㅋㅋ
# Processing: /content/all_frames/frame_20735.jpg
# Extracted text:
# 세라젬 뒤에 뻗은 먹탱이 ㅋㅋ
# Processing: /content/all_frames/frame_20764.jpg
# Extracted text:
# 세라젬 뒤에 뻗은 먹탱이 ㅋㅋ
# Processing: /content/all_frames/frame_20793.jpg
# Extracted text:
# 먹태는 빗질을 하루라도 안 해주면 안 되는데
# Processing: /content/all_frames/frame_20822.jpg
# Extracted text:
# 먹태는 빗질을 하루라도 안 해주면 안 되는데
# Processing: /content/all_frames/frame_20851.jpg
# Extracted text:
# 먹태는 빗질을 하루라도 안 해주면 안 되는데
# Processing: /content/all_frames/frame_20880.jpg
# Extracted text:
# 먹태는 빗질을 하루라도 안 해주면 안 되는데
# Processing: /content/all_frames/frame_20909.jpg
# Extracted text:
# "근데 최근에 너무 바빠가지고
# Processing: /content/all_frames/frame_20938.jpg
# Extracted text:
# "근데 최근에 너무 바빠가지고
# Processing: /content/all_frames/frame_20967.jpg
# Extracted text:
# 한 4일정도 못해줬거든요?
# Processing: /content/all_frames/frame_20996.jpg
# Extracted text:
# 말도 못하게 꼬인 먹태 털들.
# Processing: /content/all_frames/frame_21025.jpg
# Extracted text:
# 말도 못하게 꼬인 먹태 털들.
# Processing: /content/all_frames/frame_21054.jpg
# Extracted text:
# 지금 털 빗긴다고
# Processing: /content/all_frames/frame_21083.jpg
# Extracted text:
# 지금 털 빗긴다고
# Processing: /content/all_frames/frame_21112.jpg
# Extracted text:
# 두시간 반 넘은 것 같기도 해요 왠지
# Processing: /content/all_frames/frame_21141.jpg
# Extracted text:
# 두시간 반 넘은 것 같기도 해요 왠지
# Processing: /content/all_frames/frame_21170.jpg
# Extracted text:
# (허리 숙인 채로 계속 있었더니)
# 허리가 너무 아프.. 너무 아프고..
# Processing: /content/all_frames/frame_21199.jpg
# Extracted text:
# (허리 숙인 채로 계속 있었더니)
# 허리가 너무 아프.. 너무 아프고...
# Processing: /content/all_frames/frame_21228.jpg
# Extracted text:
# (힘들어서 지침)
# Processing: /content/all_frames/frame_21257.jpg
# Extracted text:
# 최대한 안 아프게 빗긴다고 시간이 더 걸렸습니다
# Processing: /content/all_frames/frame_21286.jpg
# Extracted text:
# 최대한 안 아프게 빗긴다고 시간이 더 걸렸습니다
# Processing: /content/all_frames/frame_21315.jpg
# Extracted text:
# 최대한 안 아프게 빗긴다고 시간이 더 걸렸습니다
# Processing: /content/all_frames/frame_21344.jpg
# Extracted text:
# 내일은 유준이 병원을 가야될 거 같아요!
# Processing: /content/all_frames/frame_21373.jpg
# Extracted text:
# 내일은 유준이 병원을 가야될 거 같아요!
# Processing: /content/all_frames/frame_21402.jpg
# Extracted text:
# 내일은 유준이 병원을 가야될 거 같아요
# Processing: /content/all_frames/frame_21431.jpg
# Extracted text:
# 왜냐면 유준이가
# Processing: /content/all_frames/frame_21460.jpg
# Extracted text:
# 오른쪽 귀 옆에 염증이 났었던 유준이
# Processing: /content/all_frames/frame_21489.jpg
# Extracted text:
# 오른쪽 귀 옆에 염증이 났었던 유준이
# Processing: /content/all_frames/frame_21518.jpg
# Extracted text:
# 오른쪽 귀 옆에 염증이 났었던 유준이
# Processing: /content/all_frames/frame_21547.jpg
# Extracted text:
# 병원에 가서 연고 받고 연고를 발라줬는데
# Processing: /content/all_frames/frame_21576.jpg
# Extracted text:
# 병원에 가서 연고 받고 연고를 발라줬는데
# Processing: /content/all_frames/frame_21605.jpg
# Extracted text:
# 병원에 가서 연고 받고 연고를 발라줬는데
# Processing: /content/all_frames/frame_21634.jpg
# Extracted text:
# 그 뒤로도 계속 귀를 이렇게 자기가
# Processing: /content/all_frames/frame_21663.jpg
# Extracted text:
# 그 뒤로도 계속 귀를 이렇게 자기가
# Processing: /content/all_frames/frame_21692.jpg
# Extracted text:
# 그 뒤로도 계속 귀를 이렇게 자기가
# Processing: /content/all_frames/frame_21721.jpg
# Extracted text:
# 염증난 부위가 간지러운지 계속 긁는 유준이
# Processing: /content/all_frames/frame_21750.jpg
# Extracted text:
# 염증난 부위가 간지러운지 계속 긁는 유준이
# Processing: /content/all_frames/frame_21779.jpg
# Extracted text:
# 염증난 부위가 간지러운지 계속 긁는 유준이
# Processing: /content/all_frames/frame_21808.jpg
# Extracted text:
# 오늘 보니까 유준이 귀에서
# Processing: /content/all_frames/frame_21837.jpg
# Extracted text:
# 오늘 보니까 유준이 귀에서
# Processing: /content/all_frames/frame_21866.jpg
# Extracted text:
# 살짝 꼬릿한 냄새가 나는 거죠
# Processing: /content/all_frames/frame_21895.jpg
# Extracted text:
# (목욕하다가 들어간 느낌)
# 그래서 왠지 물 들어가서 그런 거 같은데..
# Processing: /content/all_frames/frame_21924.jpg
# Extracted text:
# (목욕하다가 들어간 느낌)
# 그래서 왠지 물 들어가서 그런 거 같은데..
# Processing: /content/all_frames/frame_21953.jpg
# Extracted text:
# (목욕하다가 들어간 느낌)
# 그래서 왠지 물 들어가서 그런 거 같은데..
# Processing: /content/all_frames/frame_21982.jpg
# Extracted text:
# (목욕하다가 들어간 느낌)
# 그래서 왠지 물 들어가서 그런 거 같은데..
# Processing: /content/all_frames/frame_22011.jpg
# Extracted text:
# 여기 (염증은) 다 나았는데
# Processing: /content/all_frames/frame_22040.jpg
# Extracted text:
# 귀 안에 혹시 염증이 생겼을 수도 있겠다 생각이 들어가지고
# Processing: /content/all_frames/frame_22069.jpg
# Extracted text:
# 귀 안에 혹시 염증이 생겼을 수도 있겠다 생각이 들어가지고
# Processing: /content/all_frames/frame_22098.jpg
# Extracted text:
# 귀 안에 혹시 염증이 생겼을 수도 있겠다 생각이 들어가지고
# Processing: /content/all_frames/frame_22127.jpg
# Extracted text:
# 귀 안에 혹시 염증이 생겼을 수도 있겠다 생각이 들어가지고
# Processing: /content/all_frames/frame_22156.jpg
# Extracted text:
# 귀 안에 혹시 염증이 생겼을 수도 있겠다 생각이 들어가지고
# Processing: /content/all_frames/frame_22185.jpg
# Extracted text:
# 오전에 병원에 가기로 했고
# Processing: /content/all_frames/frame_22214.jpg
# Extracted text:
# 내일 아침 일찍부터 오픈런하기 위해 먼저 잠든 조땡님
# Processing: /content/all_frames/frame_22243.jpg
# Extracted text:
# 내일 아침 일찍부터 오픈런하기 위해 먼저 잠든 조땡님
# Processing: /content/all_frames/frame_22272.jpg
# Extracted text:
# 내일 아침 일찍부터 오픈런하기 위해 먼저 잠든 조땡님
# Processing: /content/all_frames/frame_22301.jpg
# Extracted text:
# 내일 아침 일찍부터 오픈런하기 위해 먼저 잠든 조땡님
# Processing: /content/all_frames/frame_22330.jpg
# Extracted text:
# 저는..
# Processing: /content/all_frames/frame_22359.jpg
# Extracted text:
# 저는.. 얼른..
# Processing: /content/all_frames/frame_22388.jpg
# Extracted text:
# 씻고 유준이 꿈수하고
# Processing: /content/all_frames/frame_22417.jpg
# Extracted text:
# 씻고 유준이 꿈수하고
# Processing: /content/all_frames/frame_22446.jpg
# Extracted text:
# 유준이랑 같이 자야겠어요 ㅎㅎㅎ
# Processing: /content/all_frames/frame_22475.jpg
# Extracted text:
# 유준이랑 같이 자야겠어요 ㅎㅎ
# Processing: /content/all_frames/frame_22504.jpg
# Extracted text:
# 오늘 같이 자는데
# Processing: /content/all_frames/frame_22533.jpg
# Extracted text:
# 벌써 설레..♡
# Processing: /content/all_frames/frame_22562.jpg
# Extracted text:
# 벌써 설레..♡
# Processing: /content/all_frames/frame_22591.jpg
# Extracted text:
# 낮에도 같이 자긴 하는데
# Processing: /content/all_frames/frame_22620.jpg
# Extracted text:
# 낮에도 같이 자긴 하는데
# Processing: /content/all_frames/frame_22649.jpg
# Extracted text:
# 저녁에 같이 자는 건 처음이어가지고
# Processing: /content/all_frames/frame_22678.jpg
# Extracted text:
# 저녁에 같이 자는 건 처음이어가지고
# Processing: /content/all_frames/frame_22707.jpg
# Extracted text:
# 같이 자보려고요 ㅎㅎ
# Processing: /content/all_frames/frame_22736.jpg
# Extracted text:
# 쌀토끼미미의 유기농쌀가루
# 유준이 이유식 시작하려고 쌀가루샀어요!
# Processing: /content/all_frames/frame_22765.jpg
# Extracted text:
# '쌀토끼미미의 유기농쌀가루
# 유준이 이유식 시작하려고 쌀가루샀어요!
# Processing: /content/all_frames/frame_22794.jpg
# Extracted text:
# 쌀토끼미미의 유기농쌀가루
# 유준이 이유식 시작하려고 쌀가루 샀어요!
# Processing: /content/all_frames/frame_22823.jpg
# Extracted text:
# 쌀토끼미미의 유기농쌀가루
# 유준이 이유식 시작하려고쌀가루샀어요!
# Processing: /content/all_frames/frame_22852.jpg
# Extracted text:
# (고운가루)
# 하나는 1단계 완전 다 갈려져있는 쌀가루고
# Processing: /content/all_frames/frame_22881.jpg
# Extracted text:
# (고운가루)
# 하나는 1단계 완전 다 갈려져있는 쌀가루고
# Processing: /content/all_frames/frame_22910.jpg
# Extracted text:
# (고운가루)
# 하나는 1단계 완전 다 갈려져있는 쌀가루고
# Processing: /content/all_frames/frame_22939.jpg
# Extracted text:
# (고운가루)
# 하나는 1단계 완전 다 갈려져있는 쌀가루고
# Processing: /content/all_frames/frame_22968.jpg
# Extracted text:
# (고운가루)
# 하나는 1단계 완전 다 갈려져있는 쌀가루고
# Processing: /content/all_frames/frame_22997.jpg
# Extracted text:
# 2단계 중간 입자 쌀가루)
# 이거는 살짝 알갱이 있는 거!
# Processing: /content/all_frames/frame_23026.jpg
# Extracted text:
# 2단계 중간 입자 쌀가루)
# 이거는 살짝 알갱이 있는 거!
# Processing: /content/all_frames/frame_23055.jpg
# Extracted text:
# 이유식을 시작한다한다..
# Processing: /content/all_frames/frame_23084.jpg
# Extracted text:
# 이유식을 시작한다한다..
# Processing: /content/all_frames/frame_23113.jpg
# Extracted text:
# 한 일주일 전부터 말하고 있었는데..
# Processing: /content/all_frames/frame_23142.jpg
# Extracted text:
# 한 일주일 전부터 말하고 있었는데..
# Processing: /content/all_frames/frame_23171.jpg
# Extracted text:
# 한 일주일 전부터 말하고 있었는데..
# Processing: /content/all_frames/frame_23200.jpg
# Extracted text:
# 물러날 곳이 없다!
# 이제는 더 이상 물러날 곳이 없다!
# Processing: /content/all_frames/frame_23229.jpg
# Extracted text:
# 물러날 곳이 없다!
# 이제는 더 이상 물러날 곳이 없다!
# Processing: /content/all_frames/frame_23258.jpg
# Extracted text:
# 유준이는 하루에 한 번씩 유산균 먹고 있거든요?
# Processing: /content/all_frames/frame_23287.jpg
# Extracted text:
# 유준이는 하루에 한 번씩 유산균 먹고 있거든요?
# Processing: /content/all_frames/frame_23316.jpg
# Extracted text:
# 유준이는 하루에 한 번씩 유산균 먹고 있거든요?
# Processing: /content/all_frames/frame_23345.jpg
# Extracted text:
# 유준이는 하루에 한 번 씩 유산균 먹고 있거든요?
# Processing: /content/all_frames/frame_23374.jpg
# Extracted text:
# (원래는) 오전에 주다가
# Processing: /content/all_frames/frame_23403.jpg
# Extracted text:
# 몰려서 정신없이 분유 타노래)
# 오전에 저희가 비몽사몽할 때 못 주는 거예요 유산균을?
# Processing: /content/all_frames/frame_23432.jpg
# Extracted text:
# 몰려서 정신없이 분유 타노래)
# 오전에 저희가 비몽사몽할 때 못 주는 거예요 유산균을?
# Processing: /content/all_frames/frame_23461.jpg
# Extracted text:
# 올려서 정신없이 분유 타느라
# 오전에 저희가 비몽사몽할 때 못 주는 거예요 유산균을?
# Processing: /content/all_frames/frame_23490.jpg
# Extracted text:
# 올려서 정신없이 분유 타느라)
# 오전에 저희가 비몽사몽할 때 못 주는 거예요 유산균을?
# Processing: /content/all_frames/frame_23519.jpg
# Extracted text:
# 그래서 저녁으로 바꿨어요!
# Processing: /content/all_frames/frame_23548.jpg
# Extracted text:
# 그래서 저녁으로 바꿨어요
# Processing: /content/all_frames/frame_23577.jpg
# Extracted text:
# 저녁이나 꿈수할 때 주는 걸로!
# Processing: /content/all_frames/frame_23606.jpg
# Extracted text:
# 저녁이나 꿈수할 때 주는 걸로!!
# Processing: /content/all_frames/frame_23635.jpg
# Extracted text:
# 근데 확실히 유산균을 먹으니까!
# Processing: /content/all_frames/frame_23664.jpg
# Extracted text:
# 근데 확실히 유산균을 먹으니까!
# Processing: /content/all_frames/frame_23693.jpg
# Extracted text:
# ★건강한 황금변
# Processing: /content/all_frames/frame_23722.jpg
# Extracted text:
# 건강한 황금변
# Processing: /content/all_frames/frame_23751.jpg
# Extracted text:
# 원래는 그 배앓이 분유를 먹고 있어서
# Processing: /content/all_frames/frame_23780.jpg
# Extracted text:
# 원래는 그 배앓이 분유를 먹고 있어서
# Processing: /content/all_frames/frame_23809.jpg
# Extracted text:
# 원래는 그 배앓이 분유를 먹고 있어서
# Processing: /content/all_frames/frame_23838.jpg
# Extracted text:
# 유준이가 먹고있는 분유는 녹변이 나올수 있대요
# Processing: /content/all_frames/frame_23867.jpg
# Extracted text:
# 유준이가 먹고 있는 분유는 녹변이 나올 수 있대요
# Processing: /content/all_frames/frame_23896.jpg
# Extracted text:
# 유준이가 먹고 있는 분유는 녹변이 나올수 있대요
# Processing: /content/all_frames/frame_23925.jpg
# Extracted text:
# 유준이가 먹고있는 분유는 녹변이 나올 수 있대요
# Processing: /content/all_frames/frame_23954.jpg
# Extracted text:
# 유준이가 먹고 있는 분유는 녹변이 나올 수 있대요
# Processing: /content/all_frames/frame_23983.jpg
# Extracted text:
# 근데 녹변이라고 해서 비정상이 아니라
# Processing: /content/all_frames/frame_24012.jpg
# Extracted text:
# 근데 녹변이라고 해서 비정상이 아니라
# Processing: /content/all_frames/frame_24041.jpg
# Extracted text:
# 황금변, 녹변, 갈변은 정상적인 변이라고 하더라고요!
# Processing: /content/all_frames/frame_24070.jpg
# Extracted text:
# 황금변, 녹변, 갈변은 정상적인 변이라고하더라고요!
# Processing: /content/all_frames/frame_24099.jpg
# Extracted text:
# 황금변, 녹변, 갈변은 정상적인 변이라고 하더라고요!
# Processing: /content/all_frames/frame_24128.jpg
# Extracted text:
# 황금변, 녹변, 갈변은 정상적인 변이라고 하더라고요!
# Processing: /content/all_frames/frame_24157.jpg
# Extracted text:
# 황금변, 녹변, 갈변은 정상적인 변이라고 하더라고요!
# Processing: /content/all_frames/frame_24186.jpg
# Extracted text:
# 황금변, 녹변, 갈변은 정상적인 변이라고 하더라고요!
# Processing: /content/all_frames/frame_24215.jpg
# Extracted text:
# (근데) 보기에는 황금변이 좋잖아요?
# Processing: /content/all_frames/frame_24244.jpg
# Extracted text:
# 분유를 먹는데?
# Processing: /content/all_frames/frame_24273.jpg
# Extracted text:
# 유산균 먹고 난 후부터는 하루에 두 번씩 쾌변 중
# Processing: /content/all_frames/frame_24302.jpg
# Extracted text:
# 유산균 먹고 난 후부터는 하루에 두 번씩 해변 중
# Processing: /content/all_frames/frame_24331.jpg
# Extracted text:
# 유산균 먹고 난 후부터는 하루에 두 번씩 쾌변 중
# Processing: /content/all_frames/frame_24360.jpg
# Extracted text:
# 유산균 먹고 난 후부터는 하루에 두 번씩 쾌변 중
# Processing: /content/all_frames/frame_24389.jpg
# Extracted text:
# 꿈수하고 깊게 잠든 조유주니 ㅋㅋ
# Processing: /content/all_frames/frame_24418.jpg
# Extracted text:
# 꿈수하고 깊게 잠든 조유주니
# ㅋㅋ
# Processing: /content/all_frames/frame_24447.jpg
# Extracted text:
# 꿈수하고 깊게 잠든 조유주니 ㅋㅋ
# Processing: /content/all_frames/frame_24476.jpg
# Extracted text:
# 유주니 잘 자고 내일 보자♥
# Processing: /content/all_frames/frame_24505.jpg
# Extracted text:
# 유주니 잘 자고 내일 보자♥
# Processing: /content/all_frames/frame_24534.jpg
# Extracted text:
# 유주니 잘 자고 내일 보자♥
# Processing: /content/all_frames/frame_24563.jpg
# Extracted text:
# the story about
# hyeju!
# Processing: /content/all_frames/frame_24592.jpg
# Extracted text:
# *
# the story about
# hyeju!
# Processing: /content/all_frames/frame_24621.jpg
# Extracted text:
# *
# the story about
# hyeju!
# &B
# Processing: /content/all_frames/frame_24650.jpg
# Extracted text:
# the story about
# hyeju!
# Processing: /content/all_frames/frame_24679.jpg
# Extracted text:
# the story about
# hyeju!
# *
# छ
# Processing: /content/all_frames/frame_24708.jpg
# Extracted text:
# &
# &
# the story about
# hyeju!
# *
# Processing: /content/all_frames/frame_24737.jpg
# Extracted text:
# the story about
# hyeju!
# *
# छ
# Processing: /content/all_frames/frame_24766.jpg
# Extracted text:
# *
# the story about
# hyeju!
# Processing: /content/all_frames/frame_24795.jpg
# Extracted text:
# the story about
# hyeju!
# *
# &B
# All text extracted and saved to /content/output_texts/extracted_texts.txt.

# %% [markdown]
# ### **추출된 텍스트를 리스트에 튜플형식으로 저장해서 일치하는 검색어를 이용해 유튜브 타임스탬프 생성**

# %%
import os
import cv2

# FPS 추출 함수
def get_video_fps(video_path):
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    cap.release()
    return fps

# 파일 경로와 FPS 설정
video_path = "downloaded_video.mp4"
fps = get_video_fps(video_path)

# Frame 번호에서 시간 계산 함수
def frame_to_time(frame_number, fps):
    seconds = int(frame_number // fps)  # 초를 정수로 변환
    minutes = seconds // 60
    seconds %= 60
    return f"{minutes}:{seconds:02d}"  # 형식: MM:SS

# 텍스트와 시간 추출 함수
def extract_text_and_times(file_path, fps):
    text_time_list = []

    with open(file_path, "r") as f:
        lines = f.readlines()

    current_frame = None
    current_text = []
    for line in lines:
        line = line.strip()
        if line.startswith("### frame_") and line.endswith(".jpg ###"):
            if current_frame is not None and current_text:
                timestamp = frame_to_time(current_frame, fps)
                for text in current_text:
                    text_time_list.append((text, timestamp))
            current_frame = int(line.split("frame_")[1].split(".")[0])
            current_text = []
        elif line != "텍스트를 감지하지 못했습니다.":
            if current_frame is not None:
                current_text.append(line)

    if current_frame is not None and current_text:
        timestamp = frame_to_time(current_frame, fps)
        for text in current_text:
            text_time_list.append((text, timestamp))

    return text_time_list

# 검색 텍스트로 타임스탬프 링크 생성
def search_text_and_generate_links(text_time_list, search_text, youtube_url):
    base_url = youtube_url.split("&")[0]
    links = []

    for text, timestamp in text_time_list:
        if search_text in text:
            minutes, seconds = map(int, timestamp.split(":"))
            total_seconds = minutes * 60 + seconds
            links.append(total_seconds)

    return links

# 타임스탬프 그룹화 함수
def group_timestamps(links):
    if not links:
        return []

    grouped_links = []
    links.sort()

    current_group = [links[0]]
    for i in range(1, len(links)):
        if links[i] - current_group[-1] <= 1:
            current_group.append(links[i])
        else:
            grouped_links.append(min(current_group))
            current_group = [links[i]]

    if current_group:
        grouped_links.append(min(current_group))

    return grouped_links

# 실행 예시
extracted_text_file = "/content/output_texts/extracted_texts.txt"
youtube_url = "https://www.youtube.com/watch?v=BTLQXrw4ZlE"

text_time_list = extract_text_and_times(extracted_text_file, fps)
search_text = "먹태"
links = search_text_and_generate_links(text_time_list, search_text, youtube_url)
grouped_links = group_timestamps(links)

if grouped_links:
    print(f"검색어 '{search_text}'에 해당하는 타임스탬프 링크:")
    for link in grouped_links:
        print(f"{youtube_url}&t={link}s")
else:
    print("일치하는 검색어가 없습니다.")
# Out:
# 검색어 '먹태'에 해당하는 타임스탬프 링크:
# https://www.youtube.com/watch?v=BTLQXrw4ZlE&t=0s
# https://www.youtube.com/watch?v=BTLQXrw4ZlE&t=372s
# https://www.youtube.com/watch?v=BTLQXrw4ZlE&t=383s
# https://www.youtube.com/watch?v=BTLQXrw4ZlE&t=478s
# https://www.youtube.com/watch?v=BTLQXrw4ZlE&t=522s
# https://www.youtube.com/watch?v=BTLQXrw4ZlE&t=539s
# https://www.youtube.com/watch?v=BTLQXrw4ZlE&t=558s
# https://www.youtube.com/watch?v=BTLQXrw4ZlE&t=568s
# https://www.youtube.com/watch?v=BTLQXrw4ZlE&t=581s
# https://www.youtube.com/watch?v=BTLQXrw4ZlE&t=677s
# https://www.youtube.com/watch?v=BTLQXrw4ZlE&t=687s
# https://www.youtube.com/watch?v=BTLQXrw4ZlE&t=693s
# https://www.youtube.com/watch?v=BTLQXrw4ZlE&t=700s
